# %%
# %load_ext autoreload
# %autoreload 2

# %%
import elica
# from util import *
from edinetElica import edinet_elica
from edinetDB import edinetDBOperator

# %%
ENV = 'DEV'
SEAVICE_NAME = 'ELICA_EDINET'
ELICA_CONFIG	= 'elica.conf' 
DB_CONFIG		= 'db.conf' 
EDINET_CONFIG   = 'edinet.conf'
agent = elica.ELICA(ENV,SEAVICE_NAME,ELICA_CONFIG)
# Out:
# 2021-05-27 20:47:19,599:[OK]Set host: Macico.local
# 2021-05-27 20:47:19,603:elica.conf

# %%
db_obj = edinetDBOperator(ENV,SEAVICE_NAME,DB_CONFIG)
edinet = edinet_elica(ENV,SEAVICE_NAME,agent,db_obj,EDINET_CONFIG)
# Out:
# 2021-05-27 20:47:22,885:[OK]Set host: Macico.local
# 2021-05-27 20:47:22,892:db.conf
# 2021-05-27 20:47:22,897:[OK]Set host: Macico.local
# 2021-05-27 20:47:22,898:edinet.conf

# %%
edinet.fetch_search_result()
# Out:
# 2021-05-27 20:47:34,466:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W1E63020CXW1E6A020DSPSch&uji.bean=ee.bean.parent.EECommonSearchBean&PID=W1E63020&TID=W1E63021&SESSIONKEY=1621250924027&lgKbn=2&pkbn=0&skbn=0&dskb=&dflg=0&iflg=0&preId=1&row=100&idx=0&syoruiKanriNo=&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5
# 2021-05-27 20:47:37,529:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W1E63020CXW1E6A020DSPSch&uji.bean=ee.bean.parent.EECommonSearchBean&PID=W1E63020&TID=W1E63021&SESSIONKEY=1621250924027&lgKbn=2&pkbn=0&skbn=0&dskb=&dflg=0&iflg=0&preId=1&row=100&idx=0&syoruiKanriNo=&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5
# 2021-05-27 20:47:39,633:E32189-株式会社イワキ
# 2021-05-27 20:47:43,324:Done: 2022-05-21 09:22-E32189
# 2021-05-27 20:47:43,426:E31248-株式会社ファーストロジック
# 2021-05-27 20:47:47,009:Done: 2022-05-19 13:03-E31248
# 2021-05-27 20:47:47,107:E05374-株式会社デジタルホールディングス
# 2021-05-27 20:47:50,663:Done: 2022-05-18 09:13-E05374
# 2021-05-27 20:47:50,763:E04179-センコーグループホールディングス株式会社
# 2021-05-27 20:47:54,294:Done: 2022-05-17 16:05-E04179
# 2021-05-27 20:47:54,391:E04179-センコーグループホールディングス株式会社
# 2021-05-27 20:47:57,920:Done: 2022-05-17 16:04-E04179
# 2021-05-27 20:47:58,017:E03235-株式会社ノジマ
# 2021-05-27 20:48:01,547:Done: 2022-05-14 16:53-E03235
# 2021-05-27 20:48:01,640:E00204-日本基礎技術株式会社
# 2021-05-27 20:48:05,223:Done: 2022-05-14 16:50-E00204
# 2021-05-27 20:48:05,308:E05041-ＧＭＯインターネット株式会社
# 2021-05-27 20:48:08,832:Done: 2022-05-14 16:35-E05041
# 2021-05-27 20:48:08,923:E00317-株式会社安藤・間
# 2021-05-27 20:48:12,491:Done: 2022-05-14 16:16-E00317
# 2021-05-27 20:48:12,578:E01726-ナブテスコ株式会社
# 2021-05-27 20:48:16,127:Done: 2022-05-14 16:03-E01726
# 2021-05-27 20:48:16,223:E03220-株式会社アオキスーパー
# 2021-05-27 20:48:19,761:Done: 2022-05-14 15:40-E03220
# 2021-05-27 20:48:19,846:E03753-株式会社大和証券グループ本社
# 2021-05-27 20:48:23,399:Done: 2022-05-14 15:38-E03753
# 2021-05-27 20:48:23,491:E03287-株式会社西松屋チェーン
# 2021-05-27 20:48:27,075:Done: 2022-05-14 15:30-E03287
# 2021-05-27 20:48:27,178:E14197 /
# G04601-大和証券オフィス投資法人 / 大和証券オフィス投資法人
# 2021-05-27 20:48:30,746:Done: 2022-05-14 15:30-E14197 /
# G04601
# 2021-05-27 20:48:30,843:E23465-粧美堂株式会社
# 2021-05-27 20:48:34,454:Done: 2022-05-14 15:17-E23465
# 2021-05-27 20:48:34,548:E04060-野村不動産ホールディングス株式会社
# 2021-05-27 20:48:38,114:Done: 2022-05-14 15:15-E04060
# 2021-05-27 20:48:38,226:E01777-ソニーグループ株式会社
# 2021-05-27 20:48:41,810:Done: 2022-05-14 15:15-E01777
# 2021-05-27 20:48:41,905:E05646-株式会社オリエンタルコンサルタンツホールディングス
# 2021-05-27 20:48:45,440:Done: 2022-05-14 15:12-E05646
# 2021-05-27 20:48:45,530:E03856-三菱地所株式会社
# 2021-05-27 20:48:49,123:Done: 2022-05-14 15:05-E03856
# 2021-05-27 20:48:49,198:E30047-株式会社じげん
# 2021-05-27 20:48:52,673:Done: 2022-05-14 15:03-E30047
# 2021-05-27 20:48:52,766:E04460-沖縄セルラー電話株式会社
# 2021-05-27 20:48:56,149:Done: 2022-05-14 15:01-E04460
# 2021-05-27 20:48:56,238:E00692-凸版印刷株式会社
# 2021-05-27 20:48:59,620:Done: 2022-05-14 15:00-E00692
# 2021-05-27 20:48:59,712:E25148-株式会社ジェイ・エス・ビー
# 2021-05-27 20:49:03,168:Done: 2022-05-14 15:00-E25148
# 2021-05-27 20:49:03,262:E02056-株式会社メイコー
# 2021-05-27 20:49:06,730:Done: 2022-05-14 14:40-E02056
# 2021-05-27 20:49:06,822:E04764-株式会社オオバ
# 2021-05-27 20:49:10,264:Done: 2022-05-14 14:37-E04764
# 2021-05-27 20:49:10,365:E14150 /
# G04536-いちごオフィスリート投資法人 / いちごオフィスリート投資法人
# 2021-05-27 20:49:14,225:Done: 2022-05-14 14:30-E14150 /
# G04536
# 2021-05-27 20:49:14,302:E02917-株式会社アスモ
# 2021-05-27 20:49:18,147:Done: 2022-05-14 14:29-E02917
# 2021-05-27 20:49:18,225:E01157-日本ヒューム株式会社
# 2021-05-27 20:49:22,021:Done: 2022-05-14 14:10-E01157
# 2021-05-27 20:49:22,100:E00232-株式会社テノックス
# 2021-05-27 20:49:26,147:Done: 2022-05-14 13:56-E00232
# 2021-05-27 20:49:26,333:E02719-加藤産業株式会社
# 2021-05-27 20:49:30,190:Done: 2022-05-14 13:50-E02719
# 2021-05-27 20:49:30,324:E31306-ファーストコーポレーション株式会社
# 2021-05-27 20:49:33,884:Done: 2022-05-14 13:45-E31306
# 2021-05-27 20:49:33,971:E01261-東京製鐵株式会社
# 2021-05-27 20:49:37,613:Done: 2022-05-14 13:42-E01261
# 2021-05-27 20:49:37,694:E00857-天馬株式会社
# 2021-05-27 20:49:41,552:Done: 2022-05-14 13:30-E00857
# 2021-05-27 20:49:41,631:E01124-ＨＯＹＡ株式会社
# 2021-05-27 20:49:45,179:Done: 2022-05-14 13:09-E01124
# 2021-05-27 20:49:45,257:E04973-日本空調サービス株式会社
# 2021-05-27 20:49:48,785:Done: 2022-05-14 13:01-E04973
# 2021-05-27 20:49:48,862:E01944-マブチモーター株式会社
# 2021-05-27 20:49:52,432:Done: 2022-05-14 12:12-E01944
# 2021-05-27 20:49:52,506:E04319-日本通運株式会社
# 2021-05-27 20:49:56,087:Done: 2022-05-14 12:02-E04319
# 2021-05-27 20:49:56,167:E01568-株式会社丸山製作所
# 2021-05-27 20:49:59,696:Done: 2022-05-14 11:45-E01568
# 2021-05-27 20:49:59,771:E03814-株式会社日本取引所グループ
# 2021-05-27 20:50:03,336:Done: 2022-05-14 11:35-E03814
# 2021-05-27 20:50:03,417:E00725-株式会社フジシールインターナショナル
# 2021-05-27 20:50:06,956:Done: 2022-05-14 10:18-E00725
# 2021-05-27 20:50:07,034:E04826-株式会社トーカイ
# 2021-05-27 20:50:10,599:Done: 2022-05-14 10:00-E04826
# 2021-05-27 20:50:10,675:E03948-株式会社日住サービス
# 2021-05-27 20:50:14,172:Done: 2022-05-14 10:00-E03948
# 2021-05-27 20:50:14,250:E02991-コスモ・バイオ株式会社
# 2021-05-27 20:50:17,794:Done: 2022-05-14 09:59-E02991
# 2021-05-27 20:50:17,871:E00759-日産化学株式会社
# 2021-05-27 20:50:21,439:Done: 2022-05-14 09:58-E00759
# 2021-05-27 20:50:21,518:E02315-株式会社ホギメディカル
# 2021-05-27 20:50:25,121:Done: 2022-05-14 09:53-E02315
# 2021-05-27 20:50:25,195:E00897-中国塗料株式会社
# 2021-05-27 20:50:28,730:Done: 2022-05-14 09:52-E00897
# 2021-05-27 20:50:28,807:E00493-ケンコーマヨネーズ株式会社
# 2021-05-27 20:50:32,374:Done: 2022-05-14 09:40-E00493
# 2021-05-27 20:50:32,452:E02089-株式会社　ジーエス・ユアサ　コーポレーション
# 2021-05-27 20:50:35,993:Done: 2022-05-14 09:39-E02089
# 2021-05-27 20:50:36,078:E32951-株式会社日宣
# 2021-05-27 20:50:39,641:Done: 2022-05-14 09:38-E32951
# 2021-05-27 20:50:39,720:E04294-株式会社杉村倉庫
# 2021-05-27 20:50:43,238:Done: 2022-05-14 09:31-E04294
# 2021-05-27 20:50:43,316:E00766-日本曹達株式会社
# 2021-05-27 20:50:46,867:Done: 2022-05-14 09:20-E00766
# 2021-05-27 20:50:46,953:E00473-シノブフーズ株式会社
# 2021-05-27 20:50:50,536:Done: 2022-05-14 09:15-E00473
# 2021-05-27 20:50:50,621:E00524-片倉工業株式会社
# 2021-05-27 20:50:54,132:Done: 2022-05-14 09:13-E00524
# 2021-05-27 20:50:54,212:E03640-株式会社東和銀行
# 2021-05-27 20:50:57,752:Done: 2022-05-14 09:10-E03640
# 2021-05-27 20:50:57,850:E04861-株式会社ＤＴＳ
# 2021-05-27 20:51:01,443:Done: 2022-05-14 09:01-E04861
# 2021-05-27 20:51:01,519:E00085-三井住友建設株式会社
# 2021-05-27 20:51:05,078:Done: 2022-05-13 15:54-E00085
# 2021-05-27 20:51:05,154:E31056-メディカル・データ・ビジョン株式会社
# 2021-05-27 20:51:09,050:Done: 2022-05-13 15:33-E31056
# 2021-05-27 20:51:09,190:E00090-株式会社　長谷工コーポレーション
# 2021-05-27 20:51:12,796:Done: 2022-05-13 15:28-E00090
# 2021-05-27 20:51:12,878:E01127-住友大阪セメント株式会社
# 2021-05-27 20:51:16,443:Done: 2022-05-13 15:21-E01127
# 2021-05-27 20:51:16,555:E05314-いちご株式会社
# 2021-05-27 20:51:20,096:Done: 2022-05-13 15:21-E05314
# 2021-05-27 20:51:20,177:E00435-キッコーマン株式会社
# 2021-05-27 20:51:23,716:Done: 2022-05-13 14:51-E00435
# 2021-05-27 20:51:23,829:E00820-積水化学工業株式会社
# 2021-05-27 20:51:27,394:Done: 2022-05-13 14:32-E00820
# 2021-05-27 20:51:27,474:E04015-株式会社ランド
# 2021-05-27 20:51:30,992:Done: 2022-05-13 13:27-E04015
# 2021-05-27 20:51:31,098:E02813-株式会社Ｍｉｓｕｍｉ
# 2021-05-27 20:51:34,699:Done: 2022-05-13 13:25-E02813
# 2021-05-27 20:51:34,779:E04760-株式会社電通グループ
# 2021-05-27 20:51:38,412:Done: 2022-05-13 11:58-E04760
# 2021-05-27 20:51:38,514:E34148-株式会社プロレド・パートナーズ
# 2021-05-27 20:51:42,032:Done: 2022-05-13 11:09-E34148
# 2021-05-27 20:51:42,114:E01609-岡野バルブ製造株式会社
# 2021-05-27 20:51:45,674:Done: 2022-05-13 10:20-E01609
# 2021-05-27 20:51:45,754:E00197-株式会社日本ハウスホールディングス
# 2021-05-27 20:51:49,308:Done: 2022-05-13 10:13-E00197
# 2021-05-27 20:51:49,395:E02512-西華産業株式会社
# 2021-05-27 20:51:52,938:Done: 2022-05-13 10:08-E02512
# 2021-05-27 20:51:53,022:E01946-ファナック株式会社
# 2021-05-27 20:51:56,854:Done: 2022-05-13 10:05-E01946
# 2021-05-27 20:51:56,958:E00880-日油株式会社
# 2021-05-27 20:52:00,524:Done: 2022-05-13 10:01-E00880
# 2021-05-27 20:52:00,612:E00695-共同印刷株式会社
# 2021-05-27 20:52:04,161:Done: 2022-05-13 09:58-E00695
# 2021-05-27 20:52:04,241:E00883-花王株式会社
# 2021-05-27 20:52:07,820:Done: 2022-05-13 09:44-E00883
# 2021-05-27 20:52:07,898:E01111-ニッタ株式会社
# 2021-05-27 20:52:11,420:Done: 2022-05-13 09:43-E01111
# 2021-05-27 20:52:11,503:E01480-株式会社ツガミ
# 2021-05-27 20:52:15,023:Done: 2022-05-13 09:32-E01480
# 2021-05-27 20:52:15,104:E31723-株式会社土木管理総合試験所
# 2021-05-27 20:52:18,628:Done: 2022-05-13 09:01-E31723
# 2021-05-27 20:52:18,718:E02776-タキヒヨー株式会社
# 2021-05-27 20:52:22,320:Done: 2022-05-13 09:01-E02776
# 2021-05-27 20:52:22,474:E04161-北海道中央バス株式会社
# 2021-05-27 20:52:26,119:Done: 2022-05-12 16:43-E04161
# 2021-05-27 20:52:26,227:E05379-ファーマライズホールディングス株式会社
# 2021-05-27 20:52:29,768:Done: 2022-05-12 16:31-E05379
# 2021-05-27 20:52:29,855:E06141-第一生命ホールディングス株式会社
# 2021-05-27 20:52:33,405:Done: 2022-05-12 16:01-E06141
# 2021-05-27 20:52:33,556:E33384-株式会社ピー・ビーシステムズ
# 2021-05-27 20:52:37,125:Done: 2022-05-12 16:00-E33384
# 2021-05-27 20:52:37,206:E04806-ジャフコ　グループ株式会社
# 2021-05-27 20:52:40,788:Done: 2022-05-12 15:49-E04806
# 2021-05-27 20:52:40,916:E01590-アマノ株式会社
# 2021-05-27 20:52:44,446:Done: 2022-05-12 15:36-E01590
# 2021-05-27 20:52:44,526:E25686-ＪＡＬＣＯホールディングス株式会社
# 2021-05-27 20:52:48,064:Done: 2022-05-12 15:27-E25686
# 2021-05-27 20:52:48,196:E04583-東宝株式会社
# 2021-05-27 20:52:51,718:Done: 2022-05-12 15:10-E04583
# 2021-05-27 20:52:51,802:E01267-株式会社　クボタ
# 2021-05-27 20:52:55,320:Done: 2022-05-12 15:09-E01267
# 2021-05-27 20:52:55,441:E03180-株式会社ツツミ
# 2021-05-27 20:52:59,632:Done: 2022-05-12 15:05-E03180
# 2021-05-27 20:52:59,718:E02778-ソフトバンクグループ株式会社
# 2021-05-27 20:53:03,251:Done: 2022-05-12 15:00-E02778
# 2021-05-27 20:53:03,333:E02360-株式会社太陽工機
# 2021-05-27 20:53:06,952:Done: 2022-05-12 14:47-E02360
# 2021-05-27 20:53:07,042:E01766-富士通株式会社
# 2021-05-27 20:53:10,578:Done: 2022-05-12 14:29-E01766
# 2021-05-27 20:53:10,664:E32200-株式会社アカツキ
# 2021-05-27 20:53:14,228:Done: 2022-05-12 13:10-E32200
# 2021-05-27 20:53:14,308:E02275-株式会社リコー
# 2021-05-27 20:53:17,847:Done: 2022-05-12 13:06-E02275
# 2021-05-27 20:53:17,933:E32026-ＮＣホールディングス株式会社
# 2021-05-27 20:53:21,457:Done: 2022-05-12 12:05-E32026
# 2021-05-27 20:53:21,544:E32427-株式会社コメダホールディングス
# 2021-05-27 20:53:25,019:Done: 2022-05-12 11:12-E32427
# 2021-05-27 20:53:25,105:E03858-平和不動産株式会社
# 2021-05-27 20:53:28,706:Done: 2022-05-12 11:06-E03858
# 2021-05-27 20:53:28,789:E00786-日本化学産業株式会社
# 2021-05-27 20:53:32,557:Done: 2022-05-12 10:15-E00786
# 2021-05-27 20:53:32,652:E01059-コタ株式会社
# 2021-05-27 20:53:36,264:Done: 2022-05-12 10:00-E01059
# 2021-05-27 20:53:36,375:E01607-ミネベアミツミ株式会社
# 2021-05-27 20:53:40,167:Done: 2022-05-12 09:55-E01607
# 2021-05-27 20:53:40,252:E34363-プリントネット株式会社
# 2021-05-27 20:53:44,017:Done: 2022-05-12 09:41-E34363
# 2021-05-27 20:53:44,139:E03763-藍澤證券株式会社
# 2021-05-27 20:53:47,723:Done: 2022-05-12 09:30-E03763
# 2021-05-27 20:53:47,724:[DONE] Page=0
# 2021-05-27 20:53:49,098:Next Page=1
# 2021-05-27 20:53:49,237:E00143-積水ハウス株式会社
# 2021-05-27 20:53:52,799:Done: 2022-05-12 09:25-E00143
# 2021-05-27 20:53:52,895:E01130-太平洋セメント株式会社
# 2021-05-27 20:53:56,723:Done: 2022-05-12 09:12-E01130
# 2021-05-27 20:53:56,796:E00678-ユニ・チャーム株式会社
# 2021-05-27 20:54:00,298:Done: 2022-05-12 09:00-E00678
# 2021-05-27 20:54:00,372:E03497-株式会社ＭｏｎｏｔａＲＯ
# 2021-05-27 20:54:04,316:Done: 2022-05-11 16:51-E03497
# 2021-05-27 20:54:04,403:E01137-日本碍子株式会社
# 2021-05-27 20:54:07,994:Done: 2022-05-11 15:54-E01137
# 2021-05-27 20:54:08,070:E22012-グリー株式会社
# 2021-05-27 20:54:11,848:Done: 2022-05-11 15:46-E22012
# 2021-05-27 20:54:11,942:E04425-ＫＤＤＩ株式会社
# 2021-05-27 20:54:15,503:Done: 2022-05-11 15:30-E04425
# 2021-05-27 20:54:15,582:E01636-株式会社酉島製作所
# 2021-05-27 20:54:19,086:Done: 2022-05-11 15:00-E01636
# 2021-05-27 20:54:19,169:E00670-コクヨ株式会社
# 2021-05-27 20:54:22,729:Done: 2022-05-11 15:00-E00670
# 2021-05-27 20:54:22,822:E02560-株式会社山善
# 2021-05-27 20:54:26,385:Done: 2022-05-11 14:35-E02560
# 2021-05-27 20:54:26,457:E01975-日本電産株式会社
# 2021-05-27 20:54:30,031:Done: 2022-05-11 14:20-E01975
# 2021-05-27 20:54:30,123:E25867-ＫＬａｂ株式会社
# 2021-05-27 20:54:33,698:Done: 2022-05-11 13:01-E25867
# 2021-05-27 20:54:33,774:E01699-鉱研工業株式会社
# 2021-05-27 20:54:37,289:Done: 2022-05-11 11:36-E01699
# 2021-05-27 20:54:37,380:E02774-アルテック株式会社
# 2021-05-27 20:54:40,897:Done: 2022-05-11 10:39-E02774
# 2021-05-27 20:54:40,976:E01977-ミナトホールディングス株式会社
# 2021-05-27 20:54:44,491:Done: 2022-05-11 10:37-E01977
# 2021-05-27 20:54:44,566:E26086-株式会社サンセイランディック
# 2021-05-27 20:54:48,098:Done: 2022-05-11 10:36-E26086
# 2021-05-27 20:54:48,174:E00716-株式会社プロネクサス
# 2021-05-27 20:54:51,727:Done: 2022-05-11 10:26-E00716
# 2021-05-27 20:54:51,803:E01169-三谷セキサン株式会社
# 2021-05-27 20:54:55,313:Done: 2022-05-11 09:41-E01169
# 2021-05-27 20:54:55,388:E04514-東京瓦斯株式会社
# 2021-05-27 20:54:58,967:Done: 2022-05-11 09:26-E04514
# 2021-05-27 20:54:59,050:E01100-オカモト株式会社
# 2021-05-27 20:55:02,609:Done: 2022-05-11 09:26-E01100
# 2021-05-27 20:55:02,684:E02040-ＯＢＡＲＡ　ＧＲＯＵＰ株式会社
# 2021-05-27 20:55:06,261:Done: 2022-05-11 09:06-E02040
# 2021-05-27 20:55:06,338:E00080-東亜建設工業株式会社
# 2021-05-27 20:55:09,919:Done: 2022-05-10 17:00-E00080
# 2021-05-27 20:55:09,994:E04072-株式会社ディア・ライフ
# 2021-05-27 20:55:13,507:Done: 2022-05-10 16:20-E04072
# 2021-05-27 20:55:13,589:E00913-太陽ホールディングス株式会社
# 2021-05-27 20:55:17,158:Done: 2022-05-10 16:00-E00913
# 2021-05-27 20:55:17,233:E35487-株式会社フォーラムエンジニアリング
# 2021-05-27 20:55:20,764:Done: 2022-05-10 15:55-E35487
# 2021-05-27 20:55:20,842:E05599-株式会社アドウェイズ
# 2021-05-27 20:55:24,355:Done: 2022-05-10 15:51-E05599
# 2021-05-27 20:55:24,439:E05277-ロングライフホールディング株式会社
# 2021-05-27 20:55:27,929:Done: 2022-05-10 15:50-E05277
# 2021-05-27 20:55:28,031:E02905-株式会社オーハシテクニカ
# 2021-05-27 20:55:31,420:Done: 2022-05-10 15:40-E02905
# 2021-05-27 20:55:31,494:E03051-日本瓦斯株式会社
# 2021-05-27 20:55:34,868:Done: 2022-05-10 15:28-E03051
# 2021-05-27 20:55:34,946:E00520-グンゼ株式会社
# 2021-05-27 20:55:38,314:Done: 2022-05-10 15:27-E00520
# 2021-05-27 20:55:38,385:E32549-株式会社ベイカレント・コンサルティング
# 2021-05-27 20:55:41,803:Done: 2022-05-10 15:01-E32549
# 2021-05-27 20:55:41,876:E03270-株式会社コジマ
# 2021-05-27 20:55:45,295:Done: 2022-05-10 15:01-E03270
# 2021-05-27 20:55:45,373:E04021-トーセイ株式会社
# 2021-05-27 20:55:48,724:Done: 2022-05-10 15:01-E04021
# 2021-05-27 20:55:48,797:E00717-株式会社ゼンリン
# 2021-05-27 20:55:52,201:Done: 2022-05-10 15:00-E00717
# 2021-05-27 20:55:52,278:E00828-クミアイ化学工業株式会社
# 2021-05-27 20:55:55,645:Done: 2022-05-10 14:53-E00828
# 2021-05-27 20:55:55,721:E00828-クミアイ化学工業株式会社
# 2021-05-27 20:55:55,782:E01644-株式会社　桜井製作所
# 2021-05-27 20:55:59,167:Done: 2022-05-10 14:42-E01644
# 2021-05-27 20:55:59,240:E01656-日本アイ・エス・ケイ株式会社
# 2021-05-27 20:56:02,619:Done: 2022-05-10 13:09-E01656
# 2021-05-27 20:56:02,692:E02412-株式会社エフピコ
# 2021-05-27 20:56:06,061:Done: 2022-05-10 13:07-E02412
# 2021-05-27 20:56:06,177:E00464-キユーピー株式会社
# 2021-05-27 20:56:09,584:Done: 2022-05-10 11:19-E00464
# 2021-05-27 20:56:09,659:E02958-双日株式会社
# 2021-05-27 20:56:13,051:Done: 2022-05-10 11:04-E02958
# 2021-05-27 20:56:13,156:E02552-長瀬産業株式会社
# 2021-05-27 20:56:16,516:Done: 2022-05-10 11:01-E02552
# 2021-05-27 20:56:16,587:E00770-東亞合成株式会社
# 2021-05-27 20:56:19,949:Done: 2022-05-10 10:06-E00770
# 2021-05-27 20:56:20,044:E00095-大豊建設株式会社
# 2021-05-27 20:56:23,409:Done: 2022-05-10 09:55-E00095
# 2021-05-27 20:56:23,481:E34707-スター・マイカ・ホールディングス株式会社
# 2021-05-27 20:56:26,844:Done: 2022-05-10 09:47-E34707
# 2021-05-27 20:56:26,921:E03867-京阪神ビルディング株式会社
# 2021-05-27 20:56:30,293:Done: 2022-05-10 09:07-E03867
# 2021-05-27 20:56:30,367:E04283-三菱倉庫株式会社
# 2021-05-27 20:56:33,801:Done: 2022-05-10 09:06-E04283
# 2021-05-27 20:56:33,877:E00443-林兼産業株式会社
# 2021-05-27 20:56:37,286:Done: 2022-05-07 16:15-E00443
# 2021-05-27 20:56:37,364:E34053-株式会社スプリックス
# 2021-05-27 20:56:40,763:Done: 2022-05-07 16:09-E34053
# 2021-05-27 20:56:40,835:E02513-三井物産株式会社
# 2021-05-27 20:56:44,226:Done: 2022-05-07 15:55-E02513
# 2021-05-27 20:56:44,296:E05460-株式会社ディー・エヌ・エー
# 2021-05-27 20:56:47,665:Done: 2022-05-07 15:05-E05460
# 2021-05-27 20:56:47,742:E33037-株式会社Ｎｏ．１
# 2021-05-27 20:56:51,131:Done: 2022-05-07 15:03-E33037
# 2021-05-27 20:56:51,214:E31602-株式会社平山ホールディングス
# 2021-05-27 20:56:54,607:Done: 2022-05-07 13:13-E31602
# 2021-05-27 20:56:54,685:E03489-ＤＣＭホールディングス株式会社
# 2021-05-27 20:56:58,103:Done: 2022-05-07 13:07-E03489
# 2021-05-27 20:56:58,177:E31729-株式会社ラクト・ジャパン
# 2021-05-27 20:57:01,582:Done: 2022-05-07 11:52-E31729
# 2021-05-27 20:57:01,658:E00948-ゼリア新薬工業株式会社
# 2021-05-27 20:57:05,109:Done: 2022-05-07 11:41-E00948
# 2021-05-27 20:57:05,188:E02760-杉本商事株式会社
# 2021-05-27 20:57:08,579:Done: 2022-05-07 10:05-E02760
# 2021-05-27 20:57:08,658:E05096-株式会社クリーク・アンド・リバー社
# 2021-05-27 20:57:12,081:Done: 2022-05-07 09:48-E05096
# 2021-05-27 20:57:12,191:E02602-三谷商事株式会社
# 2021-05-27 20:57:15,569:Done: 2022-05-07 09:41-E02602
# 2021-05-27 20:57:15,642:E30537-株式会社フィックスターズ
# 2021-05-27 20:57:19,066:Done: 2022-05-07 09:24-E30537
# 2021-05-27 20:57:19,140:E02742-泉州電業株式会社
# 2021-05-27 20:57:22,543:Done: 2022-05-07 09:22-E02742
# 2021-05-27 20:57:22,625:E03269-アイエーグループ株式会社
# 2021-05-27 20:57:25,980:Done: 2022-05-07 09:05-E03269
# 2021-05-27 20:57:26,065:E02086-株式会社メルコホールディングス
# 2021-05-27 20:57:29,485:Done: 2022-05-07 09:04-E02086
# 2021-05-27 20:57:29,564:E01057-株式会社ソフト９９コーポレーション
# 2021-05-27 20:57:32,922:Done: 2022-05-07 09:02-E01057
# 2021-05-27 20:57:32,999:E35449-木村工機株式会社
# 2021-05-27 20:57:36,389:Done: 2022-05-06 16:39-E35449
# 2021-05-27 20:57:36,468:E26332-株式会社エムアップホールディングス
# 2021-05-27 20:57:39,859:Done: 2022-05-06 16:30-E26332
# 2021-05-27 20:57:39,940:E05453-株式会社アエリア
# 2021-05-27 20:57:43,378:Done: 2022-05-06 16:28-E05453
# 2021-05-27 20:57:43,450:E27303-株式会社アサンテ
# 2021-05-27 20:57:46,874:Done: 2022-05-06 16:01-E27303
# 2021-05-27 20:57:46,956:E02497-伊藤忠商事株式会社
# 2021-05-27 20:57:50,354:Done: 2022-05-06 15:36-E02497
# 2021-05-27 20:57:50,436:E30726-株式会社グッドコムアセット
# 2021-05-27 20:57:53,873:Done: 2022-05-06 15:27-E30726
# 2021-05-27 20:57:53,954:E04074-サムティ株式会社
# 2021-05-27 20:57:57,321:Done: 2022-05-06 15:15-E04074
# 2021-05-27 20:57:57,400:E01761-株式会社帝国電機製作所
# 2021-05-27 20:58:00,849:Done: 2022-05-06 15:12-E01761
# 2021-05-27 20:58:00,930:E33485-株式会社Ｃａｓａ
# 2021-05-27 20:58:04,301:Done: 2022-05-06 15:01-E33485
# 2021-05-27 20:58:04,381:E26369-株式会社エイチーム
# 2021-05-27 20:58:07,845:Done: 2022-05-06 15:00-E26369
# 2021-05-27 20:58:07,919:E04215-センコン物流株式会社
# 2021-05-27 20:58:11,289:Done: 2022-05-06 13:06-E04215
# 2021-05-27 20:58:11,370:E02897-株式会社エスケイジャパン
# 2021-05-27 20:58:14,757:Done: 2022-05-06 12:39-E02897
# 2021-05-27 20:58:14,829:E04005-株式会社シノケングループ
# 2021-05-27 20:58:18,208:Done: 2022-05-06 10:31-E04005
# 2021-05-27 20:58:18,288:E32571-株式会社フィル・カンパニー
# 2021-05-27 20:58:21,723:Done: 2022-05-06 10:07-E32571
# 2021-05-27 20:58:21,839:E05041-ＧＭＯインターネット株式会社
# 2021-05-27 20:58:25,255:Done: 2022-04-26 14:38-E05041
# 2021-05-27 20:58:25,334:E05041-ＧＭＯインターネット株式会社
# 2021-05-27 20:58:28,697:Done: 2022-04-26 14:25-E05041
# 2021-05-27 20:58:28,777:E03948-株式会社日住サービス
# 2021-05-27 20:58:32,229:Done: 2022-04-16 16:25-E03948
# 2021-05-27 20:58:32,316:E00828-クミアイ化学工業株式会社
# 2021-05-27 20:58:35,673:Done: 2022-04-16 15:09-E00828
# 2021-05-27 20:58:35,750:E00828-クミアイ化学工業株式会社
# 2021-05-27 20:58:35,854:E05277-ロングライフホールディング株式会社
# 2021-05-27 20:58:39,237:Done: 2022-04-16 14:22-E05277
# 2021-05-27 20:58:39,317:E01496-株式会社　牧野フライス製作所
# 2021-05-27 20:58:42,687:Done: 2022-04-16 09:07-E01496
# 2021-05-27 20:58:42,796:E01496-株式会社　牧野フライス製作所
# 2021-05-27 20:58:42,875:E00759-日産化学株式会社
# 2021-05-27 20:58:46,270:Done: 2022-04-15 16:15-E00759
# 2021-05-27 20:58:46,351:E27281-株式会社フージャースホールディングス
# 2021-05-27 20:58:49,754:Done: 2022-04-15 16:00-E27281
# 2021-05-27 20:58:49,872:E01726-ナブテスコ株式会社
# 2021-05-27 20:58:53,253:Done: 2022-04-15 16:00-E01726
# 2021-05-27 20:58:53,336:E00692-凸版印刷株式会社
# 2021-05-27 20:58:56,744:Done: 2022-04-15 15:46-E00692
# 2021-05-27 20:58:56,865:E04460-沖縄セルラー電話株式会社
# 2021-05-27 20:59:00,233:Done: 2022-04-15 15:18-E04460
# 2021-05-27 20:59:00,312:E03235-株式会社ノジマ
# 2021-05-27 20:59:03,733:Done: 2022-04-15 15:09-E03235
# 2021-05-27 20:59:03,858:E01124-ＨＯＹＡ株式会社
# 2021-05-27 20:59:07,248:Done: 2022-04-15 15:04-E01124
# 2021-05-27 20:59:07,330:E30047-株式会社じげん
# 2021-05-27 20:59:10,687:Done: 2022-04-15 15:01-E30047
# 2021-05-27 20:59:10,769:E14150 /
# G04536-いちごオフィスリート投資法人 / いちごオフィスリート投資法人
# 2021-05-27 20:59:14,161:Done: 2022-04-15 15:00-E14150 /
# G04536
# 2021-05-27 20:59:14,241:E01777-ソニーグループ株式会社
# 2021-05-27 20:59:17,613:Done: 2022-04-15 15:00-E01777
# 2021-05-27 20:59:17,694:E01405-中央発條株式会社
# 2021-05-27 20:59:21,128:Done: 2022-04-15 13:58-E01405
# 2021-05-27 20:59:21,212:E01554-アネスト岩田株式会社
# 2021-05-27 20:59:24,635:Done: 2022-04-15 13:15-E01554
# 2021-05-27 20:59:24,717:E00052-大成建設株式会社
# 2021-05-27 20:59:28,137:Done: 2022-04-15 11:10-E00052
# 2021-05-27 20:59:28,217:E32447-株式会社西日本フィナンシャルホールディングス
# 2021-05-27 20:59:31,598:Done: 2022-04-15 10:52-E32447
# 2021-05-27 20:59:31,680:E00204-日本基礎技術株式会社
# 2021-05-27 20:59:35,113:Done: 2022-04-15 10:51-E00204
# 2021-05-27 20:59:35,190:E02089-株式会社　ジーエス・ユアサ　コーポレーション
# 2021-05-27 20:59:38,568:Done: 2022-04-15 10:33-E02089
# 2021-05-27 20:59:38,648:E02450-株式会社タカラトミー
# 2021-05-27 20:59:42,030:Done: 2022-04-15 10:12-E02450
# 2021-05-27 20:59:42,032:[DONE] Page=1
# 2021-05-27 20:59:43,467:Next Page=2
# 2021-05-27 20:59:43,666:E04319-日本通運株式会社
# 2021-05-27 20:59:47,051:Done: 2022-04-15 10:05-E04319
# 2021-05-27 20:59:47,123:E00493-ケンコーマヨネーズ株式会社
# 2021-05-27 20:59:50,514:Done: 2022-04-15 09:55-E00493
# 2021-05-27 20:59:50,607:E04345-株式会社上組
# 2021-05-27 20:59:53,948:Done: 2022-04-15 09:46-E04345
# 2021-05-27 20:59:54,023:E33039-株式会社オロ
# 2021-05-27 20:59:57,414:Done: 2022-04-15 09:38-E33039
# 2021-05-27 20:59:57,504:E01944-マブチモーター株式会社
# 2021-05-27 21:00:00,863:Done: 2022-04-15 09:29-E01944
# 2021-05-27 21:00:00,934:E02991-コスモ・バイオ株式会社
# 2021-05-27 21:00:04,362:Done: 2022-04-15 09:26-E02991
# 2021-05-27 21:00:04,430:E01673-ＳＭＣ株式会社
# 2021-05-27 21:00:07,811:Done: 2022-04-15 09:24-E01673
# 2021-05-27 21:00:07,882:E02719-加藤産業株式会社
# 2021-05-27 21:00:11,255:Done: 2022-04-15 09:12-E02719
# 2021-05-27 21:00:11,324:E02761-因幡電機産業株式会社
# 2021-05-27 21:00:14,745:Done: 2022-04-15 09:12-E02761
# 2021-05-27 21:00:14,813:E34290-フロンティア・マネジメント株式会社
# 2021-05-27 21:00:18,198:Done: 2022-04-15 09:06-E34290
# 2021-05-27 21:00:18,271:E34290-フロンティア・マネジメント株式会社
# 2021-05-27 21:00:18,344:E01568-株式会社丸山製作所
# 2021-05-27 21:00:21,774:Done: 2022-04-14 16:50-E01568
# 2021-05-27 21:00:21,846:E31056-メディカル・データ・ビジョン株式会社
# 2021-05-27 21:00:25,246:Done: 2022-04-14 16:42-E31056
# 2021-05-27 21:00:25,318:E34053-株式会社スプリックス
# 2021-05-27 21:00:28,705:Done: 2022-04-14 16:28-E34053
# 2021-05-27 21:00:28,777:E02056-株式会社メイコー
# 2021-05-27 21:00:32,155:Done: 2022-04-14 16:26-E02056
# 2021-05-27 21:00:32,228:E00524-片倉工業株式会社
# 2021-05-27 21:00:35,618:Done: 2022-04-14 15:57-E00524
# 2021-05-27 21:00:35,689:E02315-株式会社ホギメディカル
# 2021-05-27 21:00:39,096:Done: 2022-04-14 15:53-E02315
# 2021-05-27 21:00:39,168:E00317-株式会社安藤・間
# 2021-05-27 21:00:42,591:Done: 2022-04-14 15:52-E00317
# 2021-05-27 21:00:42,660:E01127-住友大阪セメント株式会社
# 2021-05-27 21:00:46,019:Done: 2022-04-14 15:42-E01127
# 2021-05-27 21:00:46,097:E23465-粧美堂株式会社
# 2021-05-27 21:00:49,526:Done: 2022-04-14 15:23-E23465
# 2021-05-27 21:00:49,594:E00094-株式会社協和エクシオ
# 2021-05-27 21:00:52,995:Done: 2022-04-14 15:20-E00094
# 2021-05-27 21:00:53,083:E04426-ソフトバンク株式会社
# 2021-05-27 21:00:56,472:Done: 2022-04-14 15:02-E04426
# 2021-05-27 21:00:56,546:E03855-三井不動産株式会社
# 2021-05-27 21:01:00,000:Done: 2022-04-14 15:02-E03855
# 2021-05-27 21:01:00,076:E05646-株式会社オリエンタルコンサルタンツホールディングス
# 2021-05-27 21:01:03,466:Done: 2022-04-14 15:00-E05646
# 2021-05-27 21:01:03,571:E25148-株式会社ジェイ・エス・ビー
# 2021-05-27 21:01:06,941:Done: 2022-04-14 15:00-E25148
# 2021-05-27 21:01:07,020:E02917-株式会社アスモ
# 2021-05-27 21:01:10,431:Done: 2022-04-14 14:00-E02917
# 2021-05-27 21:01:10,516:E02917-株式会社アスモ
# 2021-05-27 21:01:10,594:E05374-株式会社デジタルホールディングス
# 2021-05-27 21:01:14,027:Done: 2022-04-14 13:59-E05374
# 2021-05-27 21:01:14,100:E00923-塩野義製薬株式会社
# 2021-05-27 21:01:17,534:Done: 2022-04-14 13:40-E00923
# 2021-05-27 21:01:17,633:E01294-パウダーテック株式会社
# 2021-05-27 21:01:21,056:Done: 2022-04-14 13:34-E01294
# 2021-05-27 21:01:21,129:E03287-株式会社西松屋チェーン
# 2021-05-27 21:01:24,508:Done: 2022-04-14 12:00-E03287
# 2021-05-27 21:01:24,581:E34148-株式会社プロレド・パートナーズ
# 2021-05-27 21:01:27,964:Done: 2022-04-14 11:52-E34148
# 2021-05-27 21:01:28,040:E00909-株式会社アサヒペン
# 2021-05-27 21:01:31,470:Done: 2022-04-14 10:10-E00909
# 2021-05-27 21:01:31,542:E01059-コタ株式会社
# 2021-05-27 21:01:34,937:Done: 2022-04-14 10:00-E01059
# 2021-05-27 21:01:35,017:E05182-株式会社フルキャストホールディングス
# 2021-05-27 21:01:38,384:Done: 2022-04-14 09:35-E05182
# 2021-05-27 21:01:38,459:E01480-株式会社ツガミ
# 2021-05-27 21:01:41,860:Done: 2022-04-14 09:11-E01480
# 2021-05-27 21:01:41,942:E32069-伊藤ハム米久ホールディングス株式会社
# 2021-05-27 21:01:45,338:Done: 2022-04-14 09:07-E32069
# 2021-05-27 21:01:45,415:E03851-株式会社Ｔ＆Ｄホールディングス
# 2021-05-27 21:01:48,801:Done: 2022-04-13 16:09-E03851
# 2021-05-27 21:01:48,903:E05314-いちご株式会社
# 2021-05-27 21:01:52,288:Done: 2022-04-13 15:11-E05314
# 2021-05-27 21:01:52,361:E03854-ＭＳ＆ＡＤインシュアランスグループホールディングス株式会社
# 2021-05-27 21:01:55,785:Done: 2022-04-13 14:40-E03854
# 2021-05-27 21:01:55,886:E00786-日本化学産業株式会社
# 2021-05-27 21:01:59,251:Done: 2022-04-13 14:10-E00786
# 2021-05-27 21:01:59,321:E02602-三谷商事株式会社
# 2021-05-27 21:02:02,722:Done: 2022-04-13 13:17-E02602
# 2021-05-27 21:02:02,800:E04817-株式会社船井総研ホールディングス
# 2021-05-27 21:02:06,272:Done: 2022-04-13 13:14-E04817
# 2021-05-27 21:02:06,352:E04960-株式会社プラザクリエイト本社
# 2021-05-27 21:02:09,722:Done: 2022-04-13 12:15-E04960
# 2021-05-27 21:02:09,799:E05592-株式会社ソリトンシステムズ
# 2021-05-27 21:02:13,244:Done: 2022-04-13 11:39-E05592
# 2021-05-27 21:02:13,319:E25686-ＪＡＬＣＯホールディングス株式会社
# 2021-05-27 21:02:16,757:Done: 2022-04-13 11:16-E25686
# 2021-05-27 21:02:16,834:E04103-阪急阪神ホールディングス株式会社
# 2021-05-27 21:02:20,220:Done: 2022-04-13 11:05-E04103
# 2021-05-27 21:02:20,297:E00725-株式会社フジシールインターナショナル
# 2021-05-27 21:02:23,654:Done: 2022-04-13 10:03-E00725
# 2021-05-27 21:02:23,731:E02813-株式会社Ｍｉｓｕｍｉ
# 2021-05-27 21:02:27,176:Done: 2022-04-13 10:01-E02813
# 2021-05-27 21:02:27,246:E03497-株式会社ＭｏｎｏｔａＲＯ
# 2021-05-27 21:02:30,639:Done: 2022-04-12 16:36-E03497
# 2021-05-27 21:02:30,717:E03184-株式会社関西スーパーマーケット
# 2021-05-27 21:02:34,127:Done: 2022-04-12 16:34-E03184
# 2021-05-27 21:02:34,227:E00857-天馬株式会社
# 2021-05-27 21:02:37,651:Done: 2022-04-12 16:17-E00857
# 2021-05-27 21:02:37,731:E04161-北海道中央バス株式会社
# 2021-05-27 21:02:41,096:Done: 2022-04-12 15:46-E04161
# 2021-05-27 21:02:41,200:E33485-株式会社Ｃａｓａ
# 2021-05-27 21:02:44,623:Done: 2022-04-12 15:43-E33485
# 2021-05-27 21:02:44,704:E14197 /
# G04601-大和証券オフィス投資法人 / 大和証券オフィス投資法人
# 2021-05-27 21:02:48,088:Done: 2022-04-12 15:30-E14197 /
# G04601
# 2021-05-27 21:02:48,167:E02289-株式会社東京精密
# 2021-05-27 21:02:51,562:Done: 2022-04-12 15:01-E02289
# 2021-05-27 21:02:51,637:E00820-積水化学工業株式会社
# 2021-05-27 21:02:55,020:Done: 2022-04-12 14:49-E00820
# 2021-05-27 21:02:55,095:E00562-セーレン株式会社
# 2021-05-27 21:02:58,516:Done: 2022-04-12 14:35-E00562
# 2021-05-27 21:02:58,595:E30537-株式会社フィックスターズ
# 2021-05-27 21:03:01,969:Done: 2022-04-12 14:22-E30537
# 2021-05-27 21:03:02,047:E31306-ファーストコーポレーション株式会社
# 2021-05-27 21:03:05,490:Done: 2022-04-12 14:15-E31306
# 2021-05-27 21:03:05,568:E04760-株式会社電通グループ
# 2021-05-27 21:03:08,926:Done: 2022-04-12 13:22-E04760
# 2021-05-27 21:03:09,011:E00789-片倉コープアグリ株式会社
# 2021-05-27 21:03:12,441:Done: 2022-04-12 12:00-E00789
# 2021-05-27 21:03:12,513:E00095-大豊建設株式会社
# 2021-05-27 21:03:15,901:Done: 2022-04-12 11:39-E00095
# 2021-05-27 21:03:15,984:E03858-平和不動産株式会社
# 2021-05-27 21:03:19,392:Done: 2022-04-12 11:09-E03858
# 2021-05-27 21:03:19,478:E01607-ミネベアミツミ株式会社
# 2021-05-27 21:03:22,903:Done: 2022-04-12 10:46-E01607
# 2021-05-27 21:03:22,985:E34363-プリントネット株式会社
# 2021-05-27 21:03:26,427:Done: 2022-04-12 10:38-E34363
# 2021-05-27 21:03:26,515:E05690-日本テクノ・ラボ株式会社
# 2021-05-27 21:03:29,951:Done: 2022-04-12 10:28-E05690
# 2021-05-27 21:03:30,032:E00197-株式会社日本ハウスホールディングス
# 2021-05-27 21:03:33,505:Done: 2022-04-12 10:26-E00197
# 2021-05-27 21:03:33,586:E00603-株式会社ゴールドウイン
# 2021-05-27 21:03:36,989:Done: 2022-04-12 10:17-E00603
# 2021-05-27 21:03:37,072:E34707-スター・マイカ・ホールディングス株式会社
# 2021-05-27 21:03:40,492:Done: 2022-04-12 10:01-E34707
# 2021-05-27 21:03:40,570:E00688-株式会社イムラ封筒
# 2021-05-27 21:03:43,966:Done: 2022-04-12 09:18-E00688
# 2021-05-27 21:03:44,042:E00897-中国塗料株式会社
# 2021-05-27 21:03:47,409:Done: 2022-04-12 09:16-E00897
# 2021-05-27 21:03:47,487:E23250-株式会社池田泉州ホールディングス
# 2021-05-27 21:03:50,928:Done: 2022-04-12 09:13-E23250
# 2021-05-27 21:03:51,013:E00464-キユーピー株式会社
# 2021-05-27 21:03:54,437:Done: 2022-04-12 09:12-E00464
# 2021-05-27 21:03:54,509:E03575-株式会社滋賀銀行
# 2021-05-27 21:03:57,960:Done: 2022-04-12 09:08-E03575
# 2021-05-27 21:03:58,038:E03867-京阪神ビルディング株式会社
# 2021-05-27 21:04:01,426:Done: 2022-04-12 09:03-E03867
# 2021-05-27 21:04:01,507:E00770-東亞合成株式会社
# 2021-05-27 21:04:04,884:Done: 2022-04-12 09:02-E00770
# 2021-05-27 21:04:05,009:E00678-ユニ・チャーム株式会社
# 2021-05-27 21:04:08,377:Done: 2022-04-12 09:00-E00678
# 2021-05-27 21:04:08,458:E00913-太陽ホールディングス株式会社
# 2021-05-27 21:04:11,883:Done: 2022-04-09 16:00-E00913
# 2021-05-27 21:04:11,982:E00880-日油株式会社
# 2021-05-27 21:04:15,361:Done: 2022-04-09 16:00-E00880
# 2021-05-27 21:04:15,433:E30042-株式会社ウエスコホールディングス
# 2021-05-27 21:04:23,776:Done: 2022-04-09 16:00-E30042
# 2021-05-27 21:04:23,841:E00670-コクヨ株式会社
# 2021-05-27 21:04:32,194:Done: 2022-04-09 15:31-E00670
# 2021-05-27 21:04:32,267:E00090-株式会社　長谷工コーポレーション
# 2021-05-27 21:04:41,145:Done: 2022-04-09 15:25-E00090
# 2021-05-27 21:04:41,220:E00080-東亜建設工業株式会社
# 2021-05-27 21:04:49,598:Done: 2022-04-09 15:13-E00080
# 2021-05-27 21:04:49,669:E05221-株式会社ドリームインキュベータ
# 2021-05-27 21:04:58,027:Done: 2022-04-09 15:06-E05221
# 2021-05-27 21:04:58,108:E04060-野村不動産ホールディングス株式会社
# 2021-05-27 21:05:06,485:Done: 2022-04-09 15:03-E04060
# 2021-05-27 21:05:06,556:E00717-株式会社ゼンリン
# 2021-05-27 21:05:15,372:Done: 2022-04-09 15:00-E00717
# 2021-05-27 21:05:15,447:E02441-永大化工株式会社
# 2021-05-27 21:05:24,230:Done: 2022-04-09 14:46-E02441
# 2021-05-27 21:05:24,300:E00085-三井住友建設株式会社
# 2021-05-27 21:05:32,992:Done: 2022-04-09 14:33-E00085
# 2021-05-27 21:05:33,062:E02390-株式会社エンプラス
# 2021-05-27 21:05:41,505:Done: 2022-04-09 13:35-E02390
# 2021-05-27 21:05:41,577:E00962-キッセイ薬品工業株式会社
# 2021-05-27 21:05:49,966:Done: 2022-04-09 13:00-E00962
# 2021-05-27 21:05:50,039:E04973-日本空調サービス株式会社
# 2021-05-27 21:05:58,768:Done: 2022-04-09 13:00-E04973
# 2021-05-27 21:05:58,840:E02774-アルテック株式会社
# 2021-05-27 21:06:07,201:Done: 2022-04-09 11:53-E02774
# 2021-05-27 21:06:07,275:E04414-株式会社テレビ朝日ホールディングス
# 2021-05-27 21:06:16,041:Done: 2022-04-09 11:38-E04414
# 2021-05-27 21:06:16,113:E04285-株式会社住友倉庫
# 2021-05-27 21:06:24,666:Done: 2022-04-09 11:25-E04285
# 2021-05-27 21:06:24,737:E00766-日本曹達株式会社
# 2021-05-27 21:06:33,256:Done: 2022-04-09 11:22-E00766
# 2021-05-27 21:06:33,328:E02412-株式会社エフピコ
# 2021-05-27 21:06:41,892:Done: 2022-04-09 11:19-E02412
# 2021-05-27 21:06:41,964:E03847-東京海上ホールディングス株式会社
# 2021-05-27 21:06:50,387:Done: 2022-04-09 10:37-E03847
# 2021-05-27 21:06:50,460:E00911-アトミクス株式会社
# 2021-05-27 21:06:59,006:Done: 2022-04-09 10:00-E00911
# 2021-05-27 21:06:59,087:E04826-株式会社トーカイ
# 2021-05-27 21:07:07,629:Done: 2022-04-09 10:00-E04826
# 2021-05-27 21:07:07,704:E00883-花王株式会社
# 2021-05-27 21:07:16,610:Done: 2022-04-09 09:48-E00883
# 2021-05-27 21:07:16,687:E03640-株式会社東和銀行
# 2021-05-27 21:07:25,187:Done: 2022-04-09 09:08-E03640
# 2021-05-27 21:07:25,188:[DONE] Page=2
# 2021-05-27 21:07:31,675:Next Page=3
# 2021-05-27 21:07:31,774:E04283-三菱倉庫株式会社
# 2021-05-27 21:07:39,861:Detail screen error(L2): list index out of range
# Traceback (most recent call last):
#   File "/Users/macico/Dropbox/adhoc_python/edinet/edinetElica.py", line 280, in fetch_search_result
#     self.agent.driver.switch_to.window(self.agent.driver.window_handles[1])
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-1c8958231398> in <module>
# ----> 1 edinet.fetch_search_result()
#
# ~/Dropbox/adhoc_python/edinet/edinetElica.py in fetch_search_result(self)
#     298                     logging.warning("Detail screen error(L1): {0}".format(e),exc_info=True)
#     299
# --> 300                 self.db_obj.insert_search_result(row_result)
#     301                 page_result.append(row_result)
#     302                 logging.info("Done: {0}-{1}".format(row_result['submit_date'],row_result['edinet_code']))
#
# ~/Dropbox/adhoc_python/edinet/edinetDB.py in insert_search_result(self, result)
#      88                         "EDINET_CODE":result['edinet_code'],
#      89                         "SUBMITTER_NAME":result['submitter_name'],
# ---> 90                         "DETAIL_URL":result['detail_url'],
#      91                         "PDF_URL":result['pdf_url'],
#      92                         "XBRL_URL":None,
#
# KeyError: 'detail_url'

# %%
# edinet.fetch_search_result_db()
# edinet.search_result_in_db

# %%
edinet.fetch_detail_form_search()
# Out:
# 2021-05-27 20:16:37,684:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LDIO
# 2021-05-27 20:16:38,746:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LDIO
# 2021-05-27 20:16:41,976:Find 5 rows. Look up rows
# 2021-05-27 20:16:42,013:['取締役会（2021年４月16日）での決議状況', '（取得期間\u30002021年５月14日～2021年６月30日）', '270000', '200000000', '報告月における取得自己株式（取得日）', '日', '計', '報告月末現在の累計取得自己株式', '自己株式取得の進捗状況（％）']
# 2021-05-27 20:16:42,014:No Daily
# 2021-05-27 20:16:42,015:Daily report: 0 rows are fetched.
# 2021-05-27 20:16:42,018:[DONE] Inserted Daily EdinetCode=E32189, Date=20220521, 0/0
# 2021-05-27 20:16:42,025:{0: {'daily': [], 'total': None, 'daily_total': 0}}
# 2021-05-27 20:16:42,027:[DONE] Inserted Sum ID=0,EdinetCode=E32189, Date=20220521, Val=0, Amount=0, Cnt=0
# 2021-05-27 20:16:42,036:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LD46
# 2021-05-27 20:16:42,898:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LD46
# 2021-05-27 20:16:46,428:Find 7 rows. Look up rows
# 2021-05-27 20:16:46,460:['区分', '株式数（株）', '価額の総額（円）', '取締役会（2020年12月14日）での決議状況', '（取得期間\u30002020年12月15日～2021年４月30日）', '400000', '200000000', '報告月における取得自己株式（取得日）', '計', '報告月末現在の累計取得自己株式', '258000', '199980600', '自己株式取得の進捗状況（％）', '64.5', '99.9']
# 2021-05-27 20:16:46,460:No Daily
# 2021-05-27 20:16:46,461:Daily report: 0 rows are fetched.
# 2021-05-27 20:16:46,464:[DONE] Inserted Daily EdinetCode=E31248, Date=20220519, 0/0
# 2021-05-27 20:16:46,465:{0: {'daily': [], 'total': None, 'daily_total': 0}}
# 2021-05-27 20:16:46,466:[DONE] Inserted Sum ID=1,EdinetCode=E31248, Date=20220519, Val=0, Amount=0, Cnt=0
# 2021-05-27 20:16:46,475:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCR3
# 2021-05-27 20:16:46,805:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCR3
# 2021-05-27 20:16:50,032:Find 25 rows. Look up rows
# 2021-05-27 20:16:50,080:['取締役会（2021年２月10日）での決議状況', '（取得期間\u30002021年２月12日～2021年６月30日）', '650000', '1000000000', '報告月における取得自己株式（取得日）', '４月１日', '5600', '11271599', '４月２日', '5500', '11147000', '４月５日', '5000', '10337300', '４月６日', '5100', '10406500', '４月７日', '5000', '10295200', '４月８日', '5200', '10525599', '４月９日', '5300', '10668799', '４月12日', '5400', '10819699', '４月13日', '5100', '10405499', '４月13日', '5300', '10628200', '４月15日', '5300', '10600199', '４月16日', '5300', '10591199', '４月19日', '5200', '10414600', '４月20日', '7000', '13702000', '４月21日', '8600', '16274700', '４月22日', '7100', '13835699', '４月23日', '7800', '14944700', '４月26日', '7900', '15054999', '４月27日', '8100', '15398900', '４月28日', '8400', '15858600', '４月30日', '8800', '16518700', '計', '132000', '259699691', '報告月末現在の累計取得自己株式', '348700', '682841682', '自己株式取得の進捗状況（％）', '53.65％', '68.28％']
# 2021-05-27 20:16:50,081:Data: {'date': '0401', 'qty': 5600, 'value': 11271599}
# 2021-05-27 20:16:50,081:Data: {'date': '0402', 'qty': 5500, 'value': 11147000}
# 2021-05-27 20:16:50,082:Data: {'date': '0405', 'qty': 5000, 'value': 10337300}
# 2021-05-27 20:16:50,084:Data: {'date': '0406', 'qty': 5100, 'value': 10406500}
# 2021-05-27 20:16:50,088:Data: {'date': '0407', 'qty': 5000, 'value': 10295200}
# 2021-05-27 20:16:50,089:Data: {'date': '0408', 'qty': 5200, 'value': 10525599}
# 2021-05-27 20:16:50,090:Data: {'date': '0409', 'qty': 5300, 'value': 10668799}
# 2021-05-27 20:16:50,091:Data: {'date': '0412', 'qty': 5400, 'value': 10819699}
# 2021-05-27 20:16:50,092:Data: {'date': '0413', 'qty': 5100, 'value': 10405499}
# 2021-05-27 20:16:50,093:Data: {'date': '0413', 'qty': 5300, 'value': 10628200}
# 2021-05-27 20:16:50,093:Data: {'date': '0415', 'qty': 5300, 'value': 10600199}
# 2021-05-27 20:16:50,094:Data: {'date': '0416', 'qty': 5300, 'value': 10591199}
# 2021-05-27 20:16:50,095:Data: {'date': '0419', 'qty': 5200, 'value': 10414600}
# 2021-05-27 20:16:50,097:Data: {'date': '0420', 'qty': 7000, 'value': 13702000}
# 2021-05-27 20:16:50,102:Data: {'date': '0421', 'qty': 8600, 'value': 16274700}
# 2021-05-27 20:16:50,103:Data: {'date': '0422', 'qty': 7100, 'value': 13835699}
# 2021-05-27 20:16:50,105:Data: {'date': '0423', 'qty': 7800, 'value': 14944700}
# 2021-05-27 20:16:50,106:Data: {'date': '0426', 'qty': 7900, 'value': 15054999}
# 2021-05-27 20:16:50,106:Data: {'date': '0427', 'qty': 8100, 'value': 15398900}
# 2021-05-27 20:16:50,107:Data: {'date': '0428', 'qty': 8400, 'value': 15858600}
# 2021-05-27 20:16:50,108:Data: {'date': '0430', 'qty': 8800, 'value': 16518700}
# 2021-05-27 20:16:50,109:Sum : {'qty': 132000, 'value': 259699691}
# 2021-05-27 20:16:50,110:Daily report: 21 rows are fetched.
# 2021-05-27 20:16:50,170:[DONE] Inserted Daily EdinetCode=E05374, Date=20220518, 21/21
# 2021-05-27 20:16:50,171:{0: {'daily': [{'date': '0401', 'qty': 5600, 'value': 11271599}, {'date': '0402', 'qty': 5500, 'value': 11147000}, {'date': '0405', 'qty': 5000, 'value': 10337300}, {'date': '0406', 'qty': 5100, 'value': 10406500}, {'date': '0407', 'qty': 5000, 'value': 10295200}, {'date': '0408', 'qty': 5200, 'value': 10525599}, {'date': '0409', 'qty': 5300, 'value': 10668799}, {'date': '0412', 'qty': 5400, 'value': 10819699}, {'date': '0413', 'qty': 5100, 'value': 10405499}, {'date': '0413', 'qty': 5300, 'value': 10628200}, {'date': '0415', 'qty': 5300, 'value': 10600199}, {'date': '0416', 'qty': 5300, 'value': 10591199}, {'date': '0419', 'qty': 5200, 'value': 10414600}, {'date': '0420', 'qty': 7000, 'value': 13702000}, {'date': '0421', 'qty': 8600, 'value': 16274700}, {'date': '0422', 'qty': 7100, 'value': 13835699}, {'date': '0423', 'qty': 7800, 'value': 14944700}, {'date': '0426', 'qty': 7900, 'value': 15054999}, {'date': '0427', 'qty': 8100, 'value': 15398900}, {'date': '0428', 'qty': 8400, 'value': 15858600}, {'date': '0430', 'qty': 8800, 'value': 16518700}], 'total': {'qty': 132000, 'value': 259699691}, 'daily_total': 21}}
# 2021-05-27 20:16:50,172:[DONE] Inserted Sum ID=2,EdinetCode=E05374, Date=20220518, Val=259699691, Amount=132000, Cnt=21
# 2021-05-27 20:16:50,178:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCO0
# 2021-05-27 20:16:50,476:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCO0
# 2021-05-27 20:16:53,723:Find 5 rows. Look up rows
# 2021-05-27 20:16:53,742:['取締役会(2021年３月２日)での決議状況', '(取得期間2021年３月３日～2021年６月30日)', '4700000', '4000000000', '報告月における取得自己株式（取得日）', '日', '計', '報告月末現在の累計取得自己株式', '3940800', '3999912000', '自己株式取得の進捗状況（％）', '83.85', '100.00']
# 2021-05-27 20:16:53,743:No Daily
# 2021-05-27 20:16:53,743:Daily report: 0 rows are fetched.
# 2021-05-27 20:16:53,744:[DONE] Inserted Daily EdinetCode=E04179, Date=20220517, 0/0
# 2021-05-27 20:16:53,745:{0: {'daily': [], 'total': None, 'daily_total': 0}}
# 2021-05-27 20:16:53,746:[DONE] Inserted Sum ID=3,EdinetCode=E04179, Date=20220517, Val=0, Amount=0, Cnt=0
# 2021-05-27 20:16:53,755:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCMY
# 2021-05-27 20:16:54,109:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCMY
# 2021-05-27 20:16:57,323:Find 5 rows. Look up rows
# 2021-05-27 20:16:57,353:['取締役会(2021年３月２日)での決議状況', '(取得期間2021年３月３日～2021年６月30日)', '4700000', '4000000000', '報告月における取得自己株式（取得日）', '3月3日', '3940800', '3999912000', '計', '3940800', '3999912000', '報告月末現在の累計取得自己株式', '3940800', '3999912000', '自己株式取得の進捗状況（％）', '83.85', '100.00']
# 2021-05-27 20:16:57,354:Data: {'date': '0303', 'qty': 3940800, 'value': 3999912000}
# 2021-05-27 20:16:57,355:Sum : {'qty': 3940800, 'value': 3999912000}
# 2021-05-27 20:16:57,356:Daily report: 1 rows are fetched.
# 2021-05-27 20:16:57,365:[DONE] Inserted Daily EdinetCode=E04179, Date=20220517, 1/1
# 2021-05-27 20:16:57,366:{0: {'daily': [{'date': '0303', 'qty': 3940800, 'value': 3999912000}], 'total': {'qty': 3940800, 'value': 3999912000}, 'daily_total': 1}}
# 2021-05-27 20:16:57,368:[DONE] Inserted Sum ID=4,EdinetCode=E04179, Date=20220517, Val=3999912000, Amount=3940800, Cnt=1
# 2021-05-27 20:16:57,378:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCCY
# 2021-05-27 20:16:57,735:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCCY
# 2021-05-27 20:17:00,961:Find 13 rows. Look up rows
# 2021-05-27 20:17:00,991:['2021年４月30日現在', '区分', '株式数(株)', '価額の総額(円)', '取締役会(2021年２月16日)での決議状況', '(取得期間2021年２月17日～2022年２月16日)', '1000000', '3000000000', '報告月における取得自己株式(取得日)', '４月１日', '18100', '50676600', '４月６日', '9500', '26568100', '４月21日', '29400', '82301900', '４月23日', '9900', '27719700', '４月26日', '16000', '44579000', '4月28日', '13600', '37449600', '4月30日', '27800', '76115900', '計', '124300', '345410800', '報告月末現在の累計取得自己株式', '197100', '548716400', '自己株式取得の進捗状況(％)', '19.71', '18.29']
# 2021-05-27 20:17:00,992:Data: {'date': '0401', 'qty': 18100, 'value': 50676600}
# 2021-05-27 20:17:00,993:Data: {'date': '0406', 'qty': 9500, 'value': 26568100}
# 2021-05-27 20:17:00,993:Data: {'date': '0421', 'qty': 29400, 'value': 82301900}
# 2021-05-27 20:17:00,994:Data: {'date': '0423', 'qty': 9900, 'value': 27719700}
# 2021-05-27 20:17:00,995:Data: {'date': '0426', 'qty': 16000, 'value': 44579000}
# 2021-05-27 20:17:00,996:Data: {'date': '0428', 'qty': 13600, 'value': 37449600}
# 2021-05-27 20:17:00,997:Data: {'date': '0430', 'qty': 27800, 'value': 76115900}
# 2021-05-27 20:17:00,998:Sum : {'qty': 124300, 'value': 345410800}
# 2021-05-27 20:17:00,999:Daily report: 7 rows are fetched.
# 2021-05-27 20:17:01,028:[DONE] Inserted Daily EdinetCode=E03235, Date=20220514, 7/7
# 2021-05-27 20:17:01,028:{0: {'daily': [{'date': '0401', 'qty': 18100, 'value': 50676600}, {'date': '0406', 'qty': 9500, 'value': 26568100}, {'date': '0421', 'qty': 29400, 'value': 82301900}, {'date': '0423', 'qty': 9900, 'value': 27719700}, {'date': '0426', 'qty': 16000, 'value': 44579000}, {'date': '0428', 'qty': 13600, 'value': 37449600}, {'date': '0430', 'qty': 27800, 'value': 76115900}], 'total': {'qty': 124300, 'value': 345410800}, 'daily_total': 7}}
# 2021-05-27 20:17:01,029:[DONE] Inserted Sum ID=5,EdinetCode=E03235, Date=20220514, Val=345410800, Amount=124300, Cnt=7
# 2021-05-27 20:17:01,035:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCFN
# 2021-05-27 20:17:01,717:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCFN
# 2021-05-27 20:17:04,953:Find 25 rows. Look up rows
# 2021-05-27 20:17:04,997:['取締役会（令和２年11月12日）での決議状況', '（取得期間\u3000令和２年11月18日～令和３年11月17日）', '2000000', '1100000000', '報告月における取得自己株式（取得日）', '４月１日', '14500', '7477000', '４月２日', '28000', '14676400', '４月５日', '13000', '6817800', '４月６日', '8400', '4348900', '４月７日', '2600', '1333200', '４月８日', '20700', '10831200', '４月９日', '14200', '7437400', '４月12日', '16100', '8428600', '４月13日', '10600', '5543200', '４月14日', '10000', '5147300', '４月15日', '3400', '1761000', '４月16日', '5700', '2942000', '４月19日', '3200', '1649800', '４月20日', '13600', '7086500', '４月21日', '17500', '9033500', '４月22日', '5400', '2810100', '４月23日', '16900', '8831800', '４月26日', '8000', '4170000', '４月27日', '8000', '4142400', '４月28日', '6900', '3521200', '４月30日', '14000', '6967700', '計', '240700', '124957000', '報告月末現在の累計取得自己株式', '1288000', '648829400', '自己株式取得の進捗状況（％）', '64.40', '58.98']
# 2021-05-27 20:17:04,997:Data: {'date': '0401', 'qty': 14500, 'value': 7477000}
# 2021-05-27 20:17:04,998:Data: {'date': '0402', 'qty': 28000, 'value': 14676400}
# 2021-05-27 20:17:04,999:Data: {'date': '0405', 'qty': 13000, 'value': 6817800}
# 2021-05-27 20:17:05,004:Data: {'date': '0406', 'qty': 8400, 'value': 4348900}
# 2021-05-27 20:17:05,007:Data: {'date': '0407', 'qty': 2600, 'value': 1333200}
# 2021-05-27 20:17:05,009:Data: {'date': '0408', 'qty': 20700, 'value': 10831200}
# 2021-05-27 20:17:05,010:Data: {'date': '0409', 'qty': 14200, 'value': 7437400}
# 2021-05-27 20:17:05,011:Data: {'date': '0412', 'qty': 16100, 'value': 8428600}
# 2021-05-27 20:17:05,012:Data: {'date': '0413', 'qty': 10600, 'value': 5543200}
# 2021-05-27 20:17:05,013:Data: {'date': '0414', 'qty': 10000, 'value': 5147300}
# 2021-05-27 20:17:05,014:Data: {'date': '0415', 'qty': 3400, 'value': 1761000}
# 2021-05-27 20:17:05,015:Data: {'date': '0416', 'qty': 5700, 'value': 2942000}
# 2021-05-27 20:17:05,016:Data: {'date': '0419', 'qty': 3200, 'value': 1649800}
# 2021-05-27 20:17:05,017:Data: {'date': '0420', 'qty': 13600, 'value': 7086500}
# 2021-05-27 20:17:05,020:Data: {'date': '0421', 'qty': 17500, 'value': 9033500}
# 2021-05-27 20:17:05,022:Data: {'date': '0422', 'qty': 5400, 'value': 2810100}
# 2021-05-27 20:17:05,023:Data: {'date': '0423', 'qty': 16900, 'value': 8831800}
# 2021-05-27 20:17:05,025:Data: {'date': '0426', 'qty': 8000, 'value': 4170000}
# 2021-05-27 20:17:05,026:Data: {'date': '0427', 'qty': 8000, 'value': 4142400}
# 2021-05-27 20:17:05,027:Data: {'date': '0428', 'qty': 6900, 'value': 3521200}
# 2021-05-27 20:17:05,028:Data: {'date': '0430', 'qty': 14000, 'value': 6967700}
# 2021-05-27 20:17:05,029:Sum : {'qty': 240700, 'value': 124957000}
# 2021-05-27 20:17:05,030:Daily report: 21 rows are fetched.
# 2021-05-27 20:17:05,084:[DONE] Inserted Daily EdinetCode=E00204, Date=20220514, 21/21
# 2021-05-27 20:17:05,085:{0: {'daily': [{'date': '0401', 'qty': 14500, 'value': 7477000}, {'date': '0402', 'qty': 28000, 'value': 14676400}, {'date': '0405', 'qty': 13000, 'value': 6817800}, {'date': '0406', 'qty': 8400, 'value': 4348900}, {'date': '0407', 'qty': 2600, 'value': 1333200}, {'date': '0408', 'qty': 20700, 'value': 10831200}, {'date': '0409', 'qty': 14200, 'value': 7437400}, {'date': '0412', 'qty': 16100, 'value': 8428600}, {'date': '0413', 'qty': 10600, 'value': 5543200}, {'date': '0414', 'qty': 10000, 'value': 5147300}, {'date': '0415', 'qty': 3400, 'value': 1761000}, {'date': '0416', 'qty': 5700, 'value': 2942000}, {'date': '0419', 'qty': 3200, 'value': 1649800}, {'date': '0420', 'qty': 13600, 'value': 7086500}, {'date': '0421', 'qty': 17500, 'value': 9033500}, {'date': '0422', 'qty': 5400, 'value': 2810100}, {'date': '0423', 'qty': 16900, 'value': 8831800}, {'date': '0426', 'qty': 8000, 'value': 4170000}, {'date': '0427', 'qty': 8000, 'value': 4142400}, {'date': '0428', 'qty': 6900, 'value': 3521200}, {'date': '0430', 'qty': 14000, 'value': 6967700}], 'total': {'qty': 240700, 'value': 124957000}, 'daily_total': 21}}
# 2021-05-27 20:17:05,085:[DONE] Inserted Sum ID=6,EdinetCode=E00204, Date=20220514, Val=124957000, Amount=240700, Cnt=21
# 2021-05-27 20:17:05,092:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCD0
# 2021-05-27 20:17:05,623:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCD0
# 2021-05-27 20:17:08,867:Find 7 rows. Look up rows
# 2021-05-27 20:17:08,888:['2021年４月30日現在', '区分', '株式数(株)', '価額の総額(円)', '取締役会(2021年２月12日)での決議状況', '(取得期間2021年２月15日～2022年２月14日)', '5000000', '5636628600', '報告月における取得自己株式(取得日)', '計', '報告月末現在の累計取得自己株式', '自己株式取得の進捗状況(％)']
# 2021-05-27 20:17:08,889:No Daily
# 2021-05-27 20:17:08,890:Daily report: 0 rows are fetched.
# 2021-05-27 20:17:08,890:[DONE] Inserted Daily EdinetCode=E05041, Date=20220514, 0/0
# 2021-05-27 20:17:08,891:{0: {'daily': [], 'total': None, 'daily_total': 0}}
# 2021-05-27 20:17:08,894:[DONE] Inserted Sum ID=7,EdinetCode=E05041, Date=20220514, Val=0, Amount=0, Cnt=0
# 2021-05-27 20:17:08,904:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LBS4
# 2021-05-27 20:17:09,245:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LBS4
# 2021-05-27 20:17:12,479:Find 25 rows. Look up rows
# 2021-05-27 20:17:12,525:['2021年４月30日現在', '区分', '株式数(株)', '価額の総額(円)', '取締役会(2020年11月10日)での決議状況', '(取得期間\u30002020年11月16日～2021年11月15日)', '18000000', '10000000000', '報告月における取得自己株式(取得日)', '４月５日', '48100', '40954800', '４月６日', '43800', '37901600', '４月７日', '43700', '38395000', '４月８日', '45200', '39556100', '４月９日', '40100', '35215100', '４月12日', '43900', '38474300', '４月13日', '46900', '40858200', '４月14日', '42600', '37241700', '４月15日', '43900', '38485100', '４月16日', '46000', '39998200', '４月19日', '45000', '39306700', '４月20日', '47200', '41035600', '４月21日', '54600', '47442500', '４月22日', '69100', '58855800', '４月23日', '61500', '51290800', '４月26日', '51800', '44219700', '４月27日', '50200', '42901400', '４月28日', '52500', '44837300', '４月30日', '49900', '42497100', '計', '926000', '799467000', '報告月末現在の累計取得自己株式', '7479500', '5734142100', '自己株式取得の進捗状況(％)', '41.55', '57.34']
# 2021-05-27 20:17:12,525:Data: {'date': '0405', 'qty': 48100, 'value': 40954800}
# 2021-05-27 20:17:12,526:Data: {'date': '0406', 'qty': 43800, 'value': 37901600}
# 2021-05-27 20:17:12,527:Data: {'date': '0407', 'qty': 43700, 'value': 38395000}
# 2021-05-27 20:17:12,528:Data: {'date': '0408', 'qty': 45200, 'value': 39556100}
# 2021-05-27 20:17:12,529:Data: {'date': '0409', 'qty': 40100, 'value': 35215100}
# 2021-05-27 20:17:12,529:Data: {'date': '0412', 'qty': 43900, 'value': 38474300}
# 2021-05-27 20:17:12,530:Data: {'date': '0413', 'qty': 46900, 'value': 40858200}
# 2021-05-27 20:17:12,531:Data: {'date': '0414', 'qty': 42600, 'value': 37241700}
# 2021-05-27 20:17:12,532:Data: {'date': '0415', 'qty': 43900, 'value': 38485100}
# 2021-05-27 20:17:12,533:Data: {'date': '0416', 'qty': 46000, 'value': 39998200}
# 2021-05-27 20:17:12,534:Data: {'date': '0419', 'qty': 45000, 'value': 39306700}
# 2021-05-27 20:17:12,535:Data: {'date': '0420', 'qty': 47200, 'value': 41035600}
# 2021-05-27 20:17:12,536:Data: {'date': '0421', 'qty': 54600, 'value': 47442500}
# 2021-05-27 20:17:12,537:Data: {'date': '0422', 'qty': 69100, 'value': 58855800}
# 2021-05-27 20:17:12,537:Data: {'date': '0423', 'qty': 61500, 'value': 51290800}
# 2021-05-27 20:17:12,538:Data: {'date': '0426', 'qty': 51800, 'value': 44219700}
# 2021-05-27 20:17:12,539:Data: {'date': '0427', 'qty': 50200, 'value': 42901400}
# 2021-05-27 20:17:12,540:Data: {'date': '0428', 'qty': 52500, 'value': 44837300}
# 2021-05-27 20:17:12,542:Data: {'date': '0430', 'qty': 49900, 'value': 42497100}
# 2021-05-27 20:17:12,542:Sum : {'qty': 926000, 'value': 799467000}
# 2021-05-27 20:17:12,543:Daily report: 19 rows are fetched.
# 2021-05-27 20:17:12,593:[DONE] Inserted Daily EdinetCode=E00317, Date=20220514, 19/19
# 2021-05-27 20:17:12,593:{0: {'daily': [{'date': '0405', 'qty': 48100, 'value': 40954800}, {'date': '0406', 'qty': 43800, 'value': 37901600}, {'date': '0407', 'qty': 43700, 'value': 38395000}, {'date': '0408', 'qty': 45200, 'value': 39556100}, {'date': '0409', 'qty': 40100, 'value': 35215100}, {'date': '0412', 'qty': 43900, 'value': 38474300}, {'date': '0413', 'qty': 46900, 'value': 40858200}, {'date': '0414', 'qty': 42600, 'value': 37241700}, {'date': '0415', 'qty': 43900, 'value': 38485100}, {'date': '0416', 'qty': 46000, 'value': 39998200}, {'date': '0419', 'qty': 45000, 'value': 39306700}, {'date': '0420', 'qty': 47200, 'value': 41035600}, {'date': '0421', 'qty': 54600, 'value': 47442500}, {'date': '0422', 'qty': 69100, 'value': 58855800}, {'date': '0423', 'qty': 61500, 'value': 51290800}, {'date': '0426', 'qty': 51800, 'value': 44219700}, {'date': '0427', 'qty': 50200, 'value': 42901400}, {'date': '0428', 'qty': 52500, 'value': 44837300}, {'date': '0430', 'qty': 49900, 'value': 42497100}], 'total': {'qty': 926000, 'value': 799467000}, 'daily_total': 19}}
# 2021-05-27 20:17:12,594:[DONE] Inserted Sum ID=8,EdinetCode=E00317, Date=20220514, Val=799467000, Amount=926000, Cnt=19
# 2021-05-27 20:17:12,600:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LBFI
# 2021-05-27 20:17:13,274:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LBFI
# 2021-05-27 20:17:16,529:Find 27 rows. Look up rows
# 2021-05-27 20:17:16,575:['2021年４月30日現在', '区分', '株式数(株)', '価額の総額(円)', '取締役会(2021年１月29日)での決議状況', '(取得期間\u30002021年２月１日～2021年12月30日)', '4400000', '20000000000', '報告月における取得自己株式(取得日)', '４月１日', '40000', '209306000', '４月２日', '37400', '201657998', '４月５日', '37800', '201624001', '４月６日', '38000', '201253000', '４月７日', '31900', '170129000', '４月８日', '31000', '167570000', '４月９日', '39500', '216494001', '４月12日', '43400', '236346001', '４月13日', '48200', '256660001', '４月14日', '51600', '269352000', '４月15日', '52100', '270392998', '４月16日', '51600', '270351001', '４月19日', '51700', '270886001', '４月20日', '52500', '269203000', '４月21日', '63300', '310605997', '４月22日', '53400', '267624000', '４月23日', '53500', '268311498', '４月26日', '51000', '257114500', '４月27日', '56400', '279665998', '４月28日', '53600', '267984000', '４月30日', '56700', '279802502', '計', '994600', '5142333497', '報告月末現在の累計取得自己株式', '2815300', '13845342973', '自己株式取得の進捗状況(％)', '63.98', '69.23']
# 2021-05-27 20:17:16,575:Data: {'date': '0401', 'qty': 40000, 'value': 209306000}
# 2021-05-27 20:17:16,576:Data: {'date': '0402', 'qty': 37400, 'value': 201657998}
# 2021-05-27 20:17:16,577:Data: {'date': '0405', 'qty': 37800, 'value': 201624001}
# 2021-05-27 20:17:16,578:Data: {'date': '0406', 'qty': 38000, 'value': 201253000}
# 2021-05-27 20:17:16,579:Data: {'date': '0407', 'qty': 31900, 'value': 170129000}
# 2021-05-27 20:17:16,580:Data: {'date': '0408', 'qty': 31000, 'value': 167570000}
# 2021-05-27 20:17:16,581:Data: {'date': '0409', 'qty': 39500, 'value': 216494001}
# 2021-05-27 20:17:16,582:Data: {'date': '0412', 'qty': 43400, 'value': 236346001}
# 2021-05-27 20:17:16,582:Data: {'date': '0413', 'qty': 48200, 'value': 256660001}
# 2021-05-27 20:17:16,583:Data: {'date': '0414', 'qty': 51600, 'value': 269352000}
# 2021-05-27 20:17:16,584:Data: {'date': '0415', 'qty': 52100, 'value': 270392998}
# 2021-05-27 20:17:16,585:Data: {'date': '0416', 'qty': 51600, 'value': 270351001}
# 2021-05-27 20:17:16,586:Data: {'date': '0419', 'qty': 51700, 'value': 270886001}
# 2021-05-27 20:17:16,587:Data: {'date': '0420', 'qty': 52500, 'value': 269203000}
# 2021-05-27 20:17:16,588:Data: {'date': '0421', 'qty': 63300, 'value': 310605997}
# 2021-05-27 20:17:16,589:Data: {'date': '0422', 'qty': 53400, 'value': 267624000}
# 2021-05-27 20:17:16,590:Data: {'date': '0423', 'qty': 53500, 'value': 268311498}
# 2021-05-27 20:17:16,591:Data: {'date': '0426', 'qty': 51000, 'value': 257114500}
# 2021-05-27 20:17:16,592:Data: {'date': '0427', 'qty': 56400, 'value': 279665998}
# 2021-05-27 20:17:16,593:Data: {'date': '0428', 'qty': 53600, 'value': 267984000}
# 2021-05-27 20:17:16,594:Data: {'date': '0430', 'qty': 56700, 'value': 279802502}
# 2021-05-27 20:17:16,595:Sum : {'qty': 994600, 'value': 5142333497}
# 2021-05-27 20:17:16,597:Daily report: 21 rows are fetched.
# 2021-05-27 20:17:16,651:[DONE] Inserted Daily EdinetCode=E01726, Date=20220514, 21/21
# 2021-05-27 20:17:16,652:{0: {'daily': [{'date': '0401', 'qty': 40000, 'value': 209306000}, {'date': '0402', 'qty': 37400, 'value': 201657998}, {'date': '0405', 'qty': 37800, 'value': 201624001}, {'date': '0406', 'qty': 38000, 'value': 201253000}, {'date': '0407', 'qty': 31900, 'value': 170129000}, {'date': '0408', 'qty': 31000, 'value': 167570000}, {'date': '0409', 'qty': 39500, 'value': 216494001}, {'date': '0412', 'qty': 43400, 'value': 236346001}, {'date': '0413', 'qty': 48200, 'value': 256660001}, {'date': '0414', 'qty': 51600, 'value': 269352000}, {'date': '0415', 'qty': 52100, 'value': 270392998}, {'date': '0416', 'qty': 51600, 'value': 270351001}, {'date': '0419', 'qty': 51700, 'value': 270886001}, {'date': '0420', 'qty': 52500, 'value': 269203000}, {'date': '0421', 'qty': 63300, 'value': 310605997}, {'date': '0422', 'qty': 53400, 'value': 267624000}, {'date': '0423', 'qty': 53500, 'value': 268311498}, {'date': '0426', 'qty': 51000, 'value': 257114500}, {'date': '0427', 'qty': 56400, 'value': 279665998}, {'date': '0428', 'qty': 53600, 'value': 267984000}, {'date': '0430', 'qty': 56700, 'value': 279802502}], 'total': {'qty': 994600, 'value': 5142333497}, 'daily_total': 21}}
# 2021-05-27 20:17:16,652:[DONE] Inserted Sum ID=9,EdinetCode=E01726, Date=20220514, Val=5142333497, Amount=994600, Cnt=21
# 2021-05-27 20:17:16,659:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LC7E
# 2021-05-27 20:17:16,999:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LC7E
# 2021-05-27 20:17:20,228:Find 7 rows. Look up rows
# 2021-05-27 20:17:20,248:['2021年４月30日現在', '区分', '株式数(株)', '価額の総額(円)', '取締役会(2021年４月14日)での決議状況', '(取得期間2021年５月６日～2021年８月５日)', '100000', '300000000', '報告月における取得自己株式(取得日)', '日', '計', '報告月末現在の累計取得自己株式', '自己株式取得の進捗状況(％)']
# 2021-05-27 20:17:20,249:No Daily
# 2021-05-27 20:17:20,249:Daily report: 0 rows are fetched.
# 2021-05-27 20:17:20,250:[DONE] Inserted Daily EdinetCode=E03220, Date=20220514, 0/0
# 2021-05-27 20:17:20,252:{0: {'daily': [], 'total': None, 'daily_total': 0}}
# 2021-05-27 20:17:20,252:[DONE] Inserted Sum ID=10,EdinetCode=E03220, Date=20220514, Val=0, Amount=0, Cnt=0
# 2021-05-27 20:17:20,262:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LBW4
# 2021-05-27 20:17:20,766:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LBW4
# 2021-05-27 20:17:24,021:Find 5 rows. Look up rows
# 2021-05-27 20:17:24,040:['取締役会（2021年４月28日）での決議状況', '（取得期間\u30002021年５月19日～2022年３月24日）', '45000000', '30000000000', '報告月における取得自己株式（取得日）', '計', '報告月末現在の累計取得自己株式', '自己株式取得の進捗状況（％）']
# 2021-05-27 20:17:24,041:No Daily
# 2021-05-27 20:17:24,041:Daily report: 0 rows are fetched.
# 2021-05-27 20:17:24,042:[DONE] Inserted Daily EdinetCode=E03753, Date=20220514, 0/0
# 2021-05-27 20:17:24,044:{0: {'daily': [], 'total': None, 'daily_total': 0}}
# 2021-05-27 20:17:24,044:[DONE] Inserted Sum ID=11,EdinetCode=E03753, Date=20220514, Val=0, Amount=0, Cnt=0
# 2021-05-27 20:17:24,053:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LAJZ
# 2021-05-27 20:17:24,364:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LAJZ
# 2021-05-27 20:17:27,594:Find 21 rows. Look up rows
# 2021-05-27 20:17:27,632:['2021年４月30日現在', '区分', '株式数(株)', '価額の総額(円)', '取締役会(2021年３月30日)での決議状況', '(取得期間2021年４月１日～2021年６月30日)', '1646000', '2000000000', '報告月における取得自己株式(取得日)', '４月１日', '77600', '129014600', '４月２日', '77600', '130468200', '４月５日', '77600', '135053700', '４月６日', '77600', '137477700', '４月７日', '77600', '137438300', '４月８日', '77600', '135264700', '４月９日', '77600', '137583800', '４月12日', '77600', '138549600', '４月13日', '77600', '142174500', '４月14日', '77600', '143634700', '４月15日', '77600', '141997000', '４月16日', '77600', '138593400', '４月19日', '77600', '135778400', '４月20日', '77600', '134948100', '４月21日', '48400', '81933100', '計', '1134800', '1999909800', '報告月末現在の累計取得自己株式', '1134800', '1999909800', '自己株式取得の進捗状況(％)', '68.94', '100.00']
# 2021-05-27 20:17:27,633:Data: {'date': '0401', 'qty': 77600, 'value': 129014600}
# 2021-05-27 20:17:27,634:Data: {'date': '0402', 'qty': 77600, 'value': 130468200}
# 2021-05-27 20:17:27,634:Data: {'date': '0405', 'qty': 77600, 'value': 135053700}
# 2021-05-27 20:17:27,635:Data: {'date': '0406', 'qty': 77600, 'value': 137477700}
# 2021-05-27 20:17:27,636:Data: {'date': '0407', 'qty': 77600, 'value': 137438300}
# 2021-05-27 20:17:27,637:Data: {'date': '0408', 'qty': 77600, 'value': 135264700}
# 2021-05-27 20:17:27,638:Data: {'date': '0409', 'qty': 77600, 'value': 137583800}
# 2021-05-27 20:17:27,639:Data: {'date': '0412', 'qty': 77600, 'value': 138549600}
# 2021-05-27 20:17:27,640:Data: {'date': '0413', 'qty': 77600, 'value': 142174500}
# 2021-05-27 20:17:27,640:Data: {'date': '0414', 'qty': 77600, 'value': 143634700}
# 2021-05-27 20:17:27,641:Data: {'date': '0415', 'qty': 77600, 'value': 141997000}
# 2021-05-27 20:17:27,642:Data: {'date': '0416', 'qty': 77600, 'value': 138593400}
# 2021-05-27 20:17:27,643:Data: {'date': '0419', 'qty': 77600, 'value': 135778400}
# 2021-05-27 20:17:27,644:Data: {'date': '0420', 'qty': 77600, 'value': 134948100}
# 2021-05-27 20:17:27,645:Data: {'date': '0421', 'qty': 48400, 'value': 81933100}
# 2021-05-27 20:17:27,646:Sum : {'qty': 1134800, 'value': 1999909800}
# 2021-05-27 20:17:27,647:Daily report: 15 rows are fetched.
# 2021-05-27 20:17:27,695:[DONE] Inserted Daily EdinetCode=E03287, Date=20220514, 15/15
# 2021-05-27 20:17:27,696:{0: {'daily': [{'date': '0401', 'qty': 77600, 'value': 129014600}, {'date': '0402', 'qty': 77600, 'value': 130468200}, {'date': '0405', 'qty': 77600, 'value': 135053700}, {'date': '0406', 'qty': 77600, 'value': 137477700}, {'date': '0407', 'qty': 77600, 'value': 137438300}, {'date': '0408', 'qty': 77600, 'value': 135264700}, {'date': '0409', 'qty': 77600, 'value': 137583800}, {'date': '0412', 'qty': 77600, 'value': 138549600}, {'date': '0413', 'qty': 77600, 'value': 142174500}, {'date': '0414', 'qty': 77600, 'value': 143634700}, {'date': '0415', 'qty': 77600, 'value': 141997000}, {'date': '0416', 'qty': 77600, 'value': 138593400}, {'date': '0419', 'qty': 77600, 'value': 135778400}, {'date': '0420', 'qty': 77600, 'value': 134948100}, {'date': '0421', 'qty': 48400, 'value': 81933100}], 'total': {'qty': 1134800, 'value': 1999909800}, 'daily_total': 15}}
# 2021-05-27 20:17:27,697:[DONE] Inserted Sum ID=12,EdinetCode=E03287, Date=20220514, Val=1999909800, Amount=1134800, Cnt=15
# 2021-05-27 20:17:27,702:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCC1
# 2021-05-27 20:17:28,028:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LCC1
# 2021-05-27 20:17:31,199:[Skip] No mutch 報告月における取得自己株式
# 2021-05-27 20:17:31,200:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LC74
# 2021-05-27 20:17:31,549:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LC74
# 2021-05-27 20:17:34,777:Find 25 rows. Look up rows
# 2021-05-27 20:17:34,820:['2021年４月30日現在', '区分', '株式数(株)', '価額の総額(円)', '取締役会(2020年11月11日)での決議状況', '(取得期間2020年11月12日～2021年６月30日)', '200000', '100000000', '報告月における取得自己株式(取得日)', '４月５日', '900', '371700', '４月６日', '1100', '456800', '４月７日', '500', '207000', '４月８日', '1400', '575600', '４月９日', '1600', '662400', '４月12日', '1800', '745100', '４月13日', '1800', '741200', '４月14日', '800', '329000', '４月15日', '1800', '744500', '４月16日', '1100', '458200', '４月19日', '1700', '707700', '４月20日', '1600', '668000', '４月21日', '1800', '752900', '４月22日', '500', '207800', '４月23日', '1600', '667900', '４月26日', '1400', '583300', '４月27日', '1800', '748400', '４月28日', '1600', '664900', '４月30日', '300', '124700', '計', '25100', '10417100', '報告月末現在の累計取得自己株式', '162200', '65126700', '自己株式取得の進捗状況(％)', '81.10', '65.13']
# 2021-05-27 20:17:34,820:Data: {'date': '0405', 'qty': 900, 'value': 371700}
# 2021-05-27 20:17:34,821:Data: {'date': '0406', 'qty': 1100, 'value': 456800}
# 2021-05-27 20:17:34,822:Data: {'date': '0407', 'qty': 500, 'value': 207000}
# 2021-05-27 20:17:34,822:Data: {'date': '0408', 'qty': 1400, 'value': 575600}
# 2021-05-27 20:17:34,823:Data: {'date': '0409', 'qty': 1600, 'value': 662400}
# 2021-05-27 20:17:34,824:Data: {'date': '0412', 'qty': 1800, 'value': 745100}
# 2021-05-27 20:17:34,825:Data: {'date': '0413', 'qty': 1800, 'value': 741200}
# 2021-05-27 20:17:34,826:Data: {'date': '0414', 'qty': 800, 'value': 329000}
# 2021-05-27 20:17:34,827:Data: {'date': '0415', 'qty': 1800, 'value': 744500}
# 2021-05-27 20:17:34,828:Data: {'date': '0416', 'qty': 1100, 'value': 458200}
# 2021-05-27 20:17:34,829:Data: {'date': '0419', 'qty': 1700, 'value': 707700}
# 2021-05-27 20:17:34,830:Data: {'date': '0420', 'qty': 1600, 'value': 668000}
# 2021-05-27 20:17:34,831:Data: {'date': '0421', 'qty': 1800, 'value': 752900}
# 2021-05-27 20:17:34,832:Data: {'date': '0422', 'qty': 500, 'value': 207800}
# 2021-05-27 20:17:34,833:Data: {'date': '0423', 'qty': 1600, 'value': 667900}
# 2021-05-27 20:17:34,834:Data: {'date': '0426', 'qty': 1400, 'value': 583300}
# 2021-05-27 20:17:34,834:Data: {'date': '0427', 'qty': 1800, 'value': 748400}
# 2021-05-27 20:17:34,835:Data: {'date': '0428', 'qty': 1600, 'value': 664900}
# 2021-05-27 20:17:34,836:Data: {'date': '0430', 'qty': 300, 'value': 124700}
# 2021-05-27 20:17:34,837:Sum : {'qty': 25100, 'value': 10417100}
# 2021-05-27 20:17:34,838:Daily report: 19 rows are fetched.
# 2021-05-27 20:17:34,885:[DONE] Inserted Daily EdinetCode=E23465, Date=20220514, 19/19
# 2021-05-27 20:17:34,886:{0: {'daily': [{'date': '0405', 'qty': 900, 'value': 371700}, {'date': '0406', 'qty': 1100, 'value': 456800}, {'date': '0407', 'qty': 500, 'value': 207000}, {'date': '0408', 'qty': 1400, 'value': 575600}, {'date': '0409', 'qty': 1600, 'value': 662400}, {'date': '0412', 'qty': 1800, 'value': 745100}, {'date': '0413', 'qty': 1800, 'value': 741200}, {'date': '0414', 'qty': 800, 'value': 329000}, {'date': '0415', 'qty': 1800, 'value': 744500}, {'date': '0416', 'qty': 1100, 'value': 458200}, {'date': '0419', 'qty': 1700, 'value': 707700}, {'date': '0420', 'qty': 1600, 'value': 668000}, {'date': '0421', 'qty': 1800, 'value': 752900}, {'date': '0422', 'qty': 500, 'value': 207800}, {'date': '0423', 'qty': 1600, 'value': 667900}, {'date': '0426', 'qty': 1400, 'value': 583300}, {'date': '0427', 'qty': 1800, 'value': 748400}, {'date': '0428', 'qty': 1600, 'value': 664900}, {'date': '0430', 'qty': 300, 'value': 124700}], 'total': {'qty': 25100, 'value': 10417100}, 'daily_total': 19}}
# 2021-05-27 20:17:34,889:[DONE] Inserted Sum ID=14,EdinetCode=E23465, Date=20220514, Val=10417100, Amount=25100, Cnt=19
# 2021-05-27 20:17:34,896:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LBT2
# 2021-05-27 20:17:35,712:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LBT2
# 2021-05-27 20:17:38,959:Find 22 rows. Look up rows
# 2021-05-27 20:17:39,011:['取締役会（2021年１月28日）での決議状況', '（取得期間\u30002021年１月29日～2021年４月26日）', '2500000', '4000000000', '報告月における取得自己株式（取得日）', '４月１日', '25700', '68150201', '４月２日', '25800', '68384099', '４月５日', '26100', '68985100', '４月６日', '26000', '68779300', '４月７日', '24800', '66627900', '４月８日', '25100', '67282999', '４月９日', '25600', '68218298', '４月12日', '25400', '67809300', '４月13日', '24900', '66742500', '４月14日', '25500', '67792900', '４月15日', '24200', '65596500', '４月16日', '23700', '65352299', '４月19日', '24200', '65608000', '４月20日', '25000', '65763200', '４月21日', '25400', '65643201', '４月22日', '24900', '64932701', '４月23日', '25000', '65126100', '４月26日', '24700', '64263099', '計', '452000', '1201057697', '報告月末現在の累計取得自己株式', '1580900', '3999874973', '自己株式取得の進捗状況（％）', '63.2', '100.0']
# 2021-05-27 20:17:39,012:Data: {'date': '0401', 'qty': 25700, 'value': 68150201}
# 2021-05-27 20:17:39,013:Data: {'date': '0402', 'qty': 25800, 'value': 68384099}
# 2021-05-27 20:17:39,015:Data: {'date': '0405', 'qty': 26100, 'value': 68985100}
# 2021-05-27 20:17:39,016:Data: {'date': '0406', 'qty': 26000, 'value': 68779300}
# 2021-05-27 20:17:39,018:Data: {'date': '0407', 'qty': 24800, 'value': 66627900}
# 2021-05-27 20:17:39,019:Data: {'date': '0408', 'qty': 25100, 'value': 67282999}
# 2021-05-27 20:17:39,020:Data: {'date': '0409', 'qty': 25600, 'value': 68218298}
# 2021-05-27 20:17:39,021:Data: {'date': '0412', 'qty': 25400, 'value': 67809300}
# 2021-05-27 20:17:39,022:Data: {'date': '0413', 'qty': 24900, 'value': 66742500}
# 2021-05-27 20:17:39,023:Data: {'date': '0414', 'qty': 25500, 'value': 67792900}
# 2021-05-27 20:17:39,024:Data: {'date': '0415', 'qty': 24200, 'value': 65596500}
# 2021-05-27 20:17:39,025:Data: {'date': '0416', 'qty': 23700, 'value': 65352299}
# 2021-05-27 20:17:39,026:Data: {'date': '0419', 'qty': 24200, 'value': 65608000}
# 2021-05-27 20:17:39,027:Data: {'date': '0420', 'qty': 25000, 'value': 65763200}
# 2021-05-27 20:17:39,028:Data: {'date': '0421', 'qty': 25400, 'value': 65643201}
# 2021-05-27 20:17:39,033:Data: {'date': '0422', 'qty': 24900, 'value': 64932701}
# 2021-05-27 20:17:39,036:Data: {'date': '0423', 'qty': 25000, 'value': 65126100}
# 2021-05-27 20:17:39,037:Data: {'date': '0426', 'qty': 24700, 'value': 64263099}
# 2021-05-27 20:17:39,038:Sum : {'qty': 452000, 'value': 1201057697}
# 2021-05-27 20:17:39,039:Daily report: 18 rows are fetched.
# 2021-05-27 20:17:39,227:[DONE] Inserted Daily EdinetCode=E04060, Date=20220514, 18/18
# 2021-05-27 20:17:39,227:{0: {'daily': [{'date': '0401', 'qty': 25700, 'value': 68150201}, {'date': '0402', 'qty': 25800, 'value': 68384099}, {'date': '0405', 'qty': 26100, 'value': 68985100}, {'date': '0406', 'qty': 26000, 'value': 68779300}, {'date': '0407', 'qty': 24800, 'value': 66627900}, {'date': '0408', 'qty': 25100, 'value': 67282999}, {'date': '0409', 'qty': 25600, 'value': 68218298}, {'date': '0412', 'qty': 25400, 'value': 67809300}, {'date': '0413', 'qty': 24900, 'value': 66742500}, {'date': '0414', 'qty': 25500, 'value': 67792900}, {'date': '0415', 'qty': 24200, 'value': 65596500}, {'date': '0416', 'qty': 23700, 'value': 65352299}, {'date': '0419', 'qty': 24200, 'value': 65608000}, {'date': '0420', 'qty': 25000, 'value': 65763200}, {'date': '0421', 'qty': 25400, 'value': 65643201}, {'date': '0422', 'qty': 24900, 'value': 64932701}, {'date': '0423', 'qty': 25000, 'value': 65126100}, {'date': '0426', 'qty': 24700, 'value': 64263099}], 'total': {'qty': 452000, 'value': 1201057697}, 'daily_total': 18}, 1: None}
# 2021-05-27 20:17:39,228:[DONE] Inserted Sum ID=15,EdinetCode=E04060, Date=20220514, Val=1201057697, Amount=452000, Cnt=18
# ...
# 2021-05-27 20:22:46,745:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LAP1
# 2021-05-27 20:22:50,010:Find 5 rows. Look up rows
# 2021-05-27 20:22:50,038:['取締役会（2021年４月30日）での決議状況', '（取得期間\u30002021年５月20日～2021年12月31日）', '600000', '2000000000', '報告月における取得自己株式（取得日）', '日', '計', '報告月末現在の累計取得自己株式', '自己株式取得の進捗状況（％）']
# 2021-05-27 20:22:50,039:No Daily
# 2021-05-27 20:22:50,040:Daily report: 0 rows are fetched.
# 2021-05-27 20:22:50,151:[DONE] Inserted Daily EdinetCode=E03858, Date=20220512, 0/0
# 2021-05-27 20:22:50,152:{0: {'daily': [], 'total': None, 'daily_total': 0}, 1: None}
# 2021-05-27 20:22:50,152:[DONE] Inserted Sum ID=94,EdinetCode=E03858, Date=20220512, Val=0, Amount=0, Cnt=0
# 2021-05-27 20:22:50,159:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LAND
# 2021-05-27 20:22:50,589:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LAND
# 2021-05-27 20:22:53,887:Find 7 rows. Look up rows
# 2021-05-27 20:22:53,911:['2021年４月30日現在', '区分', '株式数(株)', '価額の総額(円)', '取締役会(2021年２月25日)での決議状況', '(取得期間2021年２月25日～2021年５月24日)', '300000', '450000000', '報告月における取得自己株式(取得日)', '日', '計', '報告月末現在の累積取得自己株式', '0', '0', '自己株式取得の進捗状況(％)', '0％', '0％']
# 2021-05-27 20:22:53,912:No Daily
# 2021-05-27 20:22:53,915:Daily report: 0 rows are fetched.
# 2021-05-27 20:22:53,918:[DONE] Inserted Daily EdinetCode=E00786, Date=20220512, 0/0
# 2021-05-27 20:22:53,919:{0: {'daily': [], 'total': None, 'daily_total': 0}}
# 2021-05-27 20:22:53,920:[DONE] Inserted Sum ID=95,EdinetCode=E00786, Date=20220512, Val=0, Amount=0, Cnt=0
# 2021-05-27 20:22:53,928:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LA63
# 2021-05-27 20:22:54,293:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LA63
# 2021-05-27 20:22:57,729:Find 7 rows. Look up rows
# 2021-05-27 20:22:57,750:['2021年４月30日現在', '区分', '株式数(株)', '価額の総額(円)', '取締役会（2021年２月18日）での決議状況', '（取得期間\u30002021年２月25日～2021年４月30日）', '750000', '950000000', '報告月における取得自己株式(取得日)', '４月15日', '660000', '833580000', '計', '660000', '833580000', '報告月末現在の累計取得自己株式', '660000', '833580000', '自己株式取得の進捗状況(％)', '88.00', '87.75']
# 2021-05-27 20:22:57,750:Data: {'date': '0415', 'qty': 660000, 'value': 833580000}
# 2021-05-27 20:22:57,751:Sum : {'qty': 660000, 'value': 833580000}
# 2021-05-27 20:22:57,752:Daily report: 1 rows are fetched.
# 2021-05-27 20:22:57,759:[DONE] Inserted Daily EdinetCode=E01059, Date=20220512, 1/1
# 2021-05-27 20:22:57,760:{0: {'daily': [{'date': '0415', 'qty': 660000, 'value': 833580000}], 'total': {'qty': 660000, 'value': 833580000}, 'daily_total': 1}}
# 2021-05-27 20:22:57,760:[DONE] Inserted Sum ID=96,EdinetCode=E01059, Date=20220512, Val=833580000, Amount=660000, Cnt=1
# 2021-05-27 20:22:57,766:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LAMS
# 2021-05-27 20:22:58,103:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LAMS
# 2021-05-27 20:23:01,348:Find 11 rows. Look up rows
# 2021-05-27 20:23:01,386:['取締役会（2021年２月５日）での決議状況', '（取得期間\u30002021年２月８日～2021年４月30日）', '4000000', '10000000000', '報告月における取得自己株式（取得日)', '４月22日', '92500', '258347403', '４月23日', '100300', '270430795', '４月26日', '95200', '260782702', '４月27日', '96200', '262038304', '４月28日', '93200', '257456900', '４月30日', '94000', '258115803', '計', '571400', '1567171907', '報告月末現在の累計取得自己株式', '2309900', '6258570810', '自己株式取得の進捗状況（％）', '57.75', '62.59']
# 2021-05-27 20:23:01,387:Data: {'date': '0422', 'qty': 92500, 'value': 258347403}
# 2021-05-27 20:23:01,387:Data: {'date': '0423', 'qty': 100300, 'value': 270430795}
# 2021-05-27 20:23:01,388:Data: {'date': '0426', 'qty': 95200, 'value': 260782702}
# 2021-05-27 20:23:01,389:Data: {'date': '0427', 'qty': 96200, 'value': 262038304}
# 2021-05-27 20:23:01,390:Data: {'date': '0428', 'qty': 93200, 'value': 257456900}
# 2021-05-27 20:23:01,391:Data: {'date': '0430', 'qty': 94000, 'value': 258115803}
# 2021-05-27 20:23:01,392:Sum : {'qty': 571400, 'value': 1567171907}
# 2021-05-27 20:23:01,393:Daily report: 6 rows are fetched.
# 2021-05-27 20:23:01,409:[DONE] Inserted Daily EdinetCode=E01607, Date=20220512, 6/6
# 2021-05-27 20:23:01,410:{0: {'daily': [{'date': '0422', 'qty': 92500, 'value': 258347403}, {'date': '0423', 'qty': 100300, 'value': 270430795}, {'date': '0426', 'qty': 95200, 'value': 260782702}, {'date': '0427', 'qty': 96200, 'value': 262038304}, {'date': '0428', 'qty': 93200, 'value': 257456900}, {'date': '0430', 'qty': 94000, 'value': 258115803}], 'total': {'qty': 571400, 'value': 1567171907}, 'daily_total': 6}}
# 2021-05-27 20:23:01,411:[DONE] Inserted Sum ID=97,EdinetCode=E01607, Date=20220512, Val=1567171907, Amount=571400, Cnt=6
# 2021-05-27 20:23:01,417:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LAMG
# 2021-05-27 20:23:02,249:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LAMG
# 2021-05-27 20:23:05,504:Find 5 rows. Look up rows
# 2021-05-27 20:23:05,529:['取締役会（2020年９月14日）での決議状況', '（取得期間\u30002020年９月15日～2021年９月14日）', '200000', '100000000', '報告月における取得自己株式（取得日）', '日', '計', '報告月末現在の累計取得自己株式', '200000', '97591400', '自己株式取得の進捗状況（％）', '100.00', '97.59']
# 2021-05-27 20:23:05,530:No Daily
# 2021-05-27 20:23:05,531:Daily report: 0 rows are fetched.
# 2021-05-27 20:23:05,646:Find 10 rows. Look up rows
# 2021-05-27 20:23:05,674:['取締役会（2021年４月14日）での決議状況', '（取得期間\u30002021年４月15日～2022年４月14日）', '200000', '100000000', '報告月における取得自己株式（取得日）', '４月19日', '6800', '4133500', '４月20日', '6800', '4094100', '４月21日', '2200', '1332100', '４月22日', '1800', '1098600', '４月23日', '3800', '2348500', '４月26日', '3900', '2390900', '計', '25300', '15397700', '報告月末現在の累計取得自己株式', '25300', '15397700', '自己株式取得の進捗状況（％）', '12.65', '15.39']
# 2021-05-27 20:23:05,675:Data: {'date': '0419', 'qty': 6800, 'value': 4133500}
# 2021-05-27 20:23:05,675:Data: {'date': '0420', 'qty': 6800, 'value': 4094100}
# 2021-05-27 20:23:05,677:Data: {'date': '0421', 'qty': 2200, 'value': 1332100}
# 2021-05-27 20:23:05,677:Data: {'date': '0422', 'qty': 1800, 'value': 1098600}
# 2021-05-27 20:23:05,678:Data: {'date': '0423', 'qty': 3800, 'value': 2348500}
# 2021-05-27 20:23:05,679:Data: {'date': '0426', 'qty': 3900, 'value': 2390900}
# 2021-05-27 20:23:05,680:Sum : {'qty': 25300, 'value': 15397700}
# 2021-05-27 20:23:05,681:Daily report: 6 rows are fetched.
# 2021-05-27 20:23:05,682:[DONE] Inserted Daily EdinetCode=E34363, Date=20220512, 0/0
# 2021-05-27 20:23:05,683:{0: {'daily': [], 'total': None, 'daily_total': 0}, 1: {'daily': [{'date': '0419', 'qty': 6800, 'value': 4133500}, {'date': '0420', 'qty': 6800, 'value': 4094100}, {'date': '0421', 'qty': 2200, 'value': 1332100}, {'date': '0422', 'qty': 1800, 'value': 1098600}, {'date': '0423', 'qty': 3800, 'value': 2348500}, {'date': '0426', 'qty': 3900, 'value': 2390900}], 'total': {'qty': 25300, 'value': 15397700}, 'daily_total': 6}}
# 2021-05-27 20:23:05,684:[DONE] Inserted Sum ID=98,EdinetCode=E34363, Date=20220512, Val=0, Amount=0, Cnt=0
# 2021-05-27 20:23:05,704:[DONE] Inserted Daily EdinetCode=E34363, Date=20220512, 6/6
# 2021-05-27 20:23:05,704:{0: {'daily': [], 'total': None, 'daily_total': 0}, 1: {'daily': [{'date': '0419', 'qty': 6800, 'value': 4133500}, {'date': '0420', 'qty': 6800, 'value': 4094100}, {'date': '0421', 'qty': 2200, 'value': 1332100}, {'date': '0422', 'qty': 1800, 'value': 1098600}, {'date': '0423', 'qty': 3800, 'value': 2348500}, {'date': '0426', 'qty': 3900, 'value': 2390900}], 'total': {'qty': 25300, 'value': 15397700}, 'daily_total': 6}}
# 2021-05-27 20:23:05,705:[DONE] Inserted Sum ID=98,EdinetCode=E34363, Date=20220512, Val=0, Amount=0, Cnt=0
# 2021-05-27 20:23:05,710:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LAJA
# 2021-05-27 20:23:06,046:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LAJA
# 2021-05-27 20:23:09,308:Find 27 rows. Look up rows
# 2021-05-27 20:23:09,358:['2021年４月30日現在', '区分', '株式数(株)', '価額の総額(円)', '取締役会(2021年２月26日)での決議状況', '(取得期間\u30002021年３月１日～2022年２月28日)', '1500000', '1800000000', '報告月における取得自己株式(取得日)', '４月１日', '14700', '13121300', '４月２日', '4300', '4404700', '４月５日', '5700', '6019800', '４月６日', '7800', '8003200', '４月７日', '2600', '2667500', '４月８日', '16500', '16552300', '４月９日', '4500', '4606200', '４月12日', '4200', '4328500', '４月13日', '5800', '6059700', '４月14日', '5700', '5817300', '４月15日', '2700', '2802000', '４月16日', '2600', '2702400', '４月19日', '6100', '6334300', '４月20日', '6100', '6169600', '４月21日', '6300', '6341500', '４月22日', '2500', '2533200', '４月23日', '3200', '3226500', '４月26日', '4700', '4735500', '４月27日', '4000', '4009200', '４月28日', '5100', '5000200', '４月30日', '8300', '8017100', '計', '123400', '123452000', '報告月末現在の累計取得自己株式', '358900', '361115900', '自己株式取得の進捗状況(％)', '23.93', '20.06']
# 2021-05-27 20:23:09,360:Data: {'date': '0401', 'qty': 14700, 'value': 13121300}
# 2021-05-27 20:23:09,362:Data: {'date': '0402', 'qty': 4300, 'value': 4404700}
# 2021-05-27 20:23:09,363:Data: {'date': '0405', 'qty': 5700, 'value': 6019800}
# 2021-05-27 20:23:09,364:Data: {'date': '0406', 'qty': 7800, 'value': 8003200}
# 2021-05-27 20:23:09,365:Data: {'date': '0407', 'qty': 2600, 'value': 2667500}
# 2021-05-27 20:23:09,366:Data: {'date': '0408', 'qty': 16500, 'value': 16552300}
# 2021-05-27 20:23:09,367:Data: {'date': '0409', 'qty': 4500, 'value': 4606200}
# 2021-05-27 20:23:09,368:Data: {'date': '0412', 'qty': 4200, 'value': 4328500}
# 2021-05-27 20:23:09,368:Data: {'date': '0413', 'qty': 5800, 'value': 6059700}
# 2021-05-27 20:23:09,370:Data: {'date': '0414', 'qty': 5700, 'value': 5817300}
# 2021-05-27 20:23:09,370:Data: {'date': '0415', 'qty': 2700, 'value': 2802000}
# 2021-05-27 20:23:09,372:Data: {'date': '0416', 'qty': 2600, 'value': 2702400}
# 2021-05-27 20:23:09,373:Data: {'date': '0419', 'qty': 6100, 'value': 6334300}
# 2021-05-27 20:23:09,375:Data: {'date': '0420', 'qty': 6100, 'value': 6169600}
# 2021-05-27 20:23:09,376:Data: {'date': '0421', 'qty': 6300, 'value': 6341500}
# 2021-05-27 20:23:09,376:Data: {'date': '0422', 'qty': 2500, 'value': 2533200}
# 2021-05-27 20:23:09,377:Data: {'date': '0423', 'qty': 3200, 'value': 3226500}
# 2021-05-27 20:23:09,379:Data: {'date': '0426', 'qty': 4700, 'value': 4735500}
# 2021-05-27 20:23:09,379:Data: {'date': '0427', 'qty': 4000, 'value': 4009200}
# 2021-05-27 20:23:09,380:Data: {'date': '0428', 'qty': 5100, 'value': 5000200}
# 2021-05-27 20:23:09,381:Data: {'date': '0430', 'qty': 8300, 'value': 8017100}
# 2021-05-27 20:23:09,383:Sum : {'qty': 123400, 'value': 123452000}
# 2021-05-27 20:23:09,383:Daily report: 21 rows are fetched.
# 2021-05-27 20:23:09,441:[DONE] Inserted Daily EdinetCode=E03763, Date=20220512, 21/21
# 2021-05-27 20:23:09,442:{0: {'daily': [{'date': '0401', 'qty': 14700, 'value': 13121300}, {'date': '0402', 'qty': 4300, 'value': 4404700}, {'date': '0405', 'qty': 5700, 'value': 6019800}, {'date': '0406', 'qty': 7800, 'value': 8003200}, {'date': '0407', 'qty': 2600, 'value': 2667500}, {'date': '0408', 'qty': 16500, 'value': 16552300}, {'date': '0409', 'qty': 4500, 'value': 4606200}, {'date': '0412', 'qty': 4200, 'value': 4328500}, {'date': '0413', 'qty': 5800, 'value': 6059700}, {'date': '0414', 'qty': 5700, 'value': 5817300}, {'date': '0415', 'qty': 2700, 'value': 2802000}, {'date': '0416', 'qty': 2600, 'value': 2702400}, {'date': '0419', 'qty': 6100, 'value': 6334300}, {'date': '0420', 'qty': 6100, 'value': 6169600}, {'date': '0421', 'qty': 6300, 'value': 6341500}, {'date': '0422', 'qty': 2500, 'value': 2533200}, {'date': '0423', 'qty': 3200, 'value': 3226500}, {'date': '0426', 'qty': 4700, 'value': 4735500}, {'date': '0427', 'qty': 4000, 'value': 4009200}, {'date': '0428', 'qty': 5100, 'value': 5000200}, {'date': '0430', 'qty': 8300, 'value': 8017100}], 'total': {'qty': 123400, 'value': 123452000}, 'daily_total': 21}}
# 2021-05-27 20:23:09,442:[DONE] Inserted Sum ID=99,EdinetCode=E03763, Date=20220512, Val=123452000, Amount=123400, Cnt=21

# %%
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import  time
bar_pattern = '.*[-ー－―]+'
void_dt_pattern = '[月日\s]'
import re,logging

# %%
url="https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LD46"
url="https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LB7T"

# %%
edinet.agent.to_page(url)
time.sleep(2)
content=edinet.to_content_in_detail()
# Out:
# 2021-05-27 20:26:29,573:[・]Accessing Web page.. : https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LB7T
# 2021-05-27 20:26:30,285:[OK]Driver get web page: https://disclosure.edinet-fsa.go.jp/E01EW/BLMainController.jsp?uji.verb=W00Z1010initialize&uji.bean=ek.bean.EKW00Z1010Bean&PID=W1E63021&TID=W00Z1010&SESSIONKEY=1622036595096&lgKbn=2&pkbn=0&skbn=1&dskb=&askb=&dflg=0&iflg=0&preId=1&sec=&scc=&shb=&snm=&spf1=1&spf2=1&iec=&icc=&inm=&spf3=1&fdc=&fnm=&spf4=1&spf5=2&otd=220&cal=1&era=R&yer=&mon=&psr=1&pfs=5&row=100&idx=0&str=&kbn=1&flg=&syoruiKanriNo=S100LB7T

# %%
edinet.scrtutinize_contetnt_in_detail_bytext(content)
# Out:
# 2021-05-27 20:26:33,605:Find 5 rows. Look up rows
# 2021-05-27 20:26:33,633:['取締役会（2020年11月９日）での決議状況', '（取得期間\u30002020年11月10日～2021年５月31日）', '450000', '1000000000', '報告月における取得自己株式（取得日）', '日', '計', '報告月末現在の累計取得自己株式', '304100', '999735700', '自己株式取得の進捗状況（％）', '67.58', '99.97']
# 2021-05-27 20:26:33,634:No Daily
# 2021-05-27 20:26:33,635:Daily report: 0 rows are fetched.
# {0: {'daily': [], 'total': None, 'daily_total': 0}}

# %%
progress_reports = content.find_elements(By.XPATH, "//*[contains(text(), '報告月における取得自己株式')]")
content_result = {}
for type_no in  range(len(progress_reports)):
    # Expected: 株主総会決議による取得の状況】 and 【取締役会決議による取得の状況】
    content_result[type_no] = None

    #find table obj ( it is parent obj)
    parent_report_table =progress_reports[type_no]
    cannot_find_record_tr =False
    while parent_report_table.tag_name != 'tr':
        try:
            # If html tag, error
            parent_report_table = parent_report_table.find_element_by_xpath('..')
        except:
            cannot_find_record_tr = True
            break
    if cannot_find_record_tr:
        break

    # Search base on upper level tr
    parent_report_table = parent_report_table.find_element_by_xpath('..')
    report_rows = parent_report_table.find_elements_by_tag_name('tr')
    report_result = {'daily':[],'total':None}
    logging.info("Find {0} rows. Look up rows".format(len(report_rows)))

    # replace text
    table_strs = parent_report_table.text.replace(",","").replace(" ","").split("\n")
    table_strs = [ _str  for _str in [re.sub(bar_pattern,"",_str) for _str in table_strs] if _str != ""]
    logging.info(table_strs)
# Out:
# 2021-05-27 20:42:20,182:Find 5 rows. Look up rows
# 2021-05-27 20:42:20,207:['取締役会（2020年11月９日）での決議状況', '（取得期間\u30002020年11月10日～2021年５月31日）', '450000', '1000000000', '報告月における取得自己株式（取得日）', '日', '計', '報告月末現在の累計取得自己株式', '304100', '999735700', '自己株式取得の進捗状況（％）', '67.58', '99.97']

# %%
sum_idx = table_strs.index("計")
report_rows=table_strs[[ _i  for _i, _str in enumerate(table_strs) if '報告月における取得自己株式' in _str ][0]+1:sum_idx]
for _i in range(0,len(report_rows),3):
    date_col_txt =  report_rows[_i]
    if "月" in date_col_txt:
        if "日" in date_col_txt:
            if  re.match(bar_pattern, date_col_txt) is None and re.sub(void_dt_pattern, '', date_col_txt) != '':
                try:
                    month = str(int(date_col_txt.split('月')[0])).zfill(2)
                    day = str(int(date_col_txt.split('月')[1].split('日')[0])).zfill(2)
                    dt = month+day
                    qty = int(report_rows[_i+1].replace(',', ''))
                    value = int(report_rows[_i+2].replace(',', ''))
                    if qty is not None:
                        report_result['daily'].append({'date':dt,'qty':qty,'value':value})
                        logging.info("Data: {0}".format(report_result['daily'][-1]))
                    else:
                        logging.info("Data: No data")
                except:
                    logging.warning("No Daily")

# sum
qty_col_txt = table_strs[sum_idx+1]
if  re.match(bar_pattern, qty_col_txt) is None:
    try:
        sum_qty = int(qty_col_txt.replace(',', ''))
        sum_value = int(table_strs[sum_idx+2].replace(',', ''))
        if sum_qty is not None:
            report_result['total'] = {'qty':sum_qty,'value':sum_value}
            logging.info("Sum : {0}".format(report_result['total']))
        else:
            logging.info("Sum: No data")
    except Exception as e:
        logging.warning("No Daily")



report_result['daily_total'] = len(report_result['daily'])
content_result[type_no] = report_result
logging.info("Daily report: {0} rows are fetched.".format(len(report_result['daily'])))
# Out:
# 2021-05-27 20:42:24,296:No Daily
# 2021-05-27 20:42:24,297:Daily report: 0 rows are fetched.

# %%
qty_col_txt
# Out:
# '報告月末現在の累計取得自己株式'

# %%
parent_report_table =progress_reports[0]
cannot_find_record_tr =False
while parent_report_table.tag_name != 'tr':
    try:
        # If html tag, error
        parent_report_table = parent_report_table.find_element_by_xpath('..')
    except:
        cannot_find_record_tr = True
        break

# %%
parent_report_table = parent_report_table.find_element_by_xpath('..')
report_rows = parent_report_table.find_elements_by_xpath('tr')
report_result = {'daily':[],'total':None}

# %%
parent_report_table.find_elements_by_tag_name('tr')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-10")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-12")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-13")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-14")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-15")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-18")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-19")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-20")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-21")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-22")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-24")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-26")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-27")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-28")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="69985723c06d313f5cc489c4ade0a97f", element="0.9646502390909917-29")>]

# %%
import re
bar_pattern = '.*[-ー－―]+'
void_dt_pattern = '[月日\s]'

# %%
for i_report_row in range(len(report_rows)):
    report_row = report_rows[i_report_row]

    qty, value = None, None
    sum_qty, sum_value = None, None
    report_cols = report_row.find_elements_by_tag_name('td')
    print(report_cols[0].text)

    if "日現在" in report_cols[0].text:
        continue
    if len(report_cols) <=1:
        continue

    date_col_txt = report_cols[1].text
    if "月" in date_col_txt:
        if "日" in date_col_txt:
            if  re.match(bar_pattern, date_col_txt) is None and re.sub(void_dt_pattern, '', date_col_txt) != '':
                month = str(int(date_col_txt.split('月')[0])).zfill(2)
                day = str(int(date_col_txt.split('月')[1].split('日')[0])).zfill(2)
                dt = month+day
                qty = int(report_cols[2].text.replace(',', ''))
                value = int(report_cols[3].text.replace(',', ''))
                if qty is not None:
                    report_result['daily'].append({'date':dt,'qty':qty,'value':value})
#                     logging.info("Data: {0}".format(report_result['daily'][-1]))
                else:
                    logging.info("Data: No data")
# Out:
# 取締役会（令和２年11月12日）での決議状況
# （取得期間　令和２年11月18日～令和３年11月17日）
# 報告月における取得自己株式（取得日）
# ４月２日
# ４月５日
# ４月６日
# ４月７日
# ４月８日
# ４月９日
# ４月12日
# ４月13日
# ４月14日
# ４月15日
# ４月16日
# ４月19日
# ４月20日
# ４月21日
# ４月22日
# ４月23日
# ４月26日
# ４月27日
# ４月28日
# ４月30日
# 計
# 報告月末現在の累計取得自己株式
# 自己株式取得の進捗状況（％）

# %%
bar_pattern = '.*[-ー－―]+'
void_dt_pattern = '[月日\s]'

# %%
table_strs = parent_report_table.text.replace(",","").replace(" ","").split("\n")
table_strs = [ _str  for _str in [re.sub(bar_pattern,"",_str) for _str in table_strs] if _str != ""]
sum_idx = table_strs.index("計")
report_rows=table_strs[[ _i  for _i, _str in enumerate(table_strs) if '報告月における取得自己株式' in _str ][0]+1:sum_idx]
for _i in range(0,len(report_rows),3):
    date_col_txt =  report_rows[_i]
    if "月" in date_col_txt:
    if "日" in date_col_txt:
        if  re.match(bar_pattern, date_col_txt) is None and re.sub(void_dt_pattern, '', date_col_txt) != '':
            month = str(int(date_col_txt.split('月')[0])).zfill(2)
            day = str(int(date_col_txt.split('月')[1].split('日')[0])).zfill(2)
            dt = month+day
            qty = int(report_rows[_i+1].text.replace(',', ''))
            value = int(report_rows[_i+2].text.replace(',', ''))
            if qty is not None:
                report_result['daily'].append({'date':dt,'qty':qty,'value':value})
                logging.info("Data: {0}".format(report_result['daily'][-1]))
            else:
                logging.info("Data: No data")

                


qty_col_txt = table_strs[sum_idx+1]
if  re.match(bar_pattern, qty_col_txt) is None:
    sum_qty = int(qty_col_txt.text.replace(',', ''))
    sum_value = int(table_strs[sum_idx+2].text.replace(',', ''))
    if sum_qty is not None:
        report_result['total'] = {'qty':sum_qty,'value':sum_value}
        logging.info("Sum : {0}".format(report_result['total']))
    else:
        logging.info("Sum: No data")
break
# Out:
# ４月１日
# ４月２日
# ４月５日
# ４月６日
# ４月７日
# ４月８日
# ４月９日
# ４月12日
# ４月13日
# ４月14日
# ４月15日
# ４月16日
# ４月19日
# ４月20日
# ４月21日
# ４月22日
# ４月23日
# ４月26日
# ４月27日
# ４月28日
# ４月30日

# %%
# Out:
# ['取締役会（令和２年11月12日）での決議状況',
#  '（取得期間\u3000令和２年11月18日～令和３年11月17日）',
#  '2000000',
#  '1100000000',
#  '報告月における取得自己株式（取得日）',
#  '４月１日',
#  '14500',
#  '7477000',
#  '４月２日',
#  '28000',
#  '14676400',
#  '４月５日',
#  '13000',
#  '6817800',
#  '４月６日',
#  '8400',
#  '4348900',
#  '４月７日',
#  '2600',
#  '1333200',
#  '４月８日',
#  '20700',
#  '10831200',
#  '４月９日',
#  '14200',
#  '7437400',
#  '４月12日',
#  '16100',
#  '8428600',
#  '４月13日',
#  '10600',
#  '5543200',
#  '４月14日',
#  '10000',
#  '5147300',
#  '４月15日',
#  '3400',
#  '1761000',
#  '４月16日',
#  '5700',
#  '2942000',
#  '４月19日',
#  '3200',
#  '1649800',
#  '４月20日',
#  '13600',
#  '7086500',
#  '４月21日',
#  '17500',
#  '9033500',
#  '４月22日',
#  '5400',
#  '2810100',
#  '４月23日',
#  '16900',
#  '8831800',
#  '４月26日',
#  '8000',
#  '4170000',
#  '４月27日',
#  '8000',
#  '4142400',
#  '４月28日',
#  '6900',
#  '3521200',
#  '４月30日',
#  '14000',
#  '6967700',
#  '計',
#  '240700',
#  '124957000',
#  '報告月末現在の累計取得自己株式',
#  '1288000',
#  '648829400',
#  '自己株式取得の進捗状況（％）',
#  '64.40',
#  '58.98']

# %%
# Out:
# ('240700', '124957000')

# %%
report_result['total']

# %%
result = []
# get rows
table_parent = agent.driver.find_elements(By.XPATH, "//div[@class='result']")[0] # get resutl
table = table_parent.find_elements(By.XPATH, "table")[0] #get table 
rows = table.find_elements(By.XPATH, "tbody/tr[not(contains(@class,'tableHeader'))]") #get row
i_row=0
target_content = rows[i_row].find_elements(By.XPATH, "td")
target_content_submit_date = target_content[0].text
target_content_link_obj = target_content[1]
target_content_edinet_code = target_content[2].text
target_content_submitter_name= target_content[3].text
target_content_pdf_link= target_content[5].find_element_by_tag_name('a').get_attribute("href")
col_text =  target_content_link_obj.text
logging.info("{0}-{1}".format(target_content_edinet_code,target_content_submitter_name))
# if col_text != '自己株券買付状況報告書（法２４条の６第１項に基づくもの）':

progress_report_result = {'submit_date':target_content_submit_date, 'edinet_code':target_content_edinet_code, 'pdf_link':target_content_pdf_link}
# press and move activationn
target_content_link_obj.click()
time.sleep(3)
# try:
# Entry detail window
agent.driver.switch_to.window(agent.driver.window_handles[1])
progress_report_result['detail_url']= agent.driver.current_url
# try:
# Activate detail window

# Action to display Ccontent
agent.driver.switch_to.frame(agent.driver.find_elements(By.XPATH, "//frame")[1])
agent.driver.switch_to.frame(agent.driver.find_elements(By.XPATH, "//frame")[1])

leftbar_body = agent.driver.find_elements(By.XPATH, "//body")[0]
fetch_content_btn = agent.driver.find_elements(By.XPATH, "//a[contains(text(), '取得状況')]")[0]
fetch_content_btn.click()
agent.driver.switch_to.default_content()

# Action to move onto Ccontent
time.sleep(2)
agent.driver.switch_to.frame(agent.driver.find_elements(By.XPATH, "//frame")[1])
agent.driver.switch_to.frame(agent.driver.find_elements(By.XPATH, "//frame")[2])

report_content = agent.driver.find_elements(By.XPATH, "//body")[0]

# Scrtutinize contetnt
progress_reports = report_content.find_elements(By.XPATH, "//*[contains(text(), '報告月における取得自己株式')]")
# for type_no in  range(len(progress_reports)):
#     # Expected: 株主総会決議による取得の状況】 and 【取締役会決議による取得の状況】
#     progress_report_result[type_no] = None

#     #find table obj ( it is parent obj)
#     parent_report_table =progress_reports[type_no]
#     cannot_find_record_tr =False
#     while parent_report_table.tag_name != 'tr':
#         try:
#             # If html tag, error
#             parent_report_table = parent_report_table.find_element_by_xpath('..')
#         except:
#             cannot_find_record_tr = True
#             break
#     if cannot_find_record_tr:
#         break

#     # Search base on upper level tr
#     parent_report_table = parent_report_table.find_element_by_xpath('..')
#     report_rows = parent_report_table.find_elements_by_xpath('tr')
#     report_result = {'daily':[],'total':None}
#     logging.info("Find {0} rows. Look up rows".format(len(report_rows)))
#     for i_report_row in range(len(report_rows)):
#         report_row = report_rows[i_report_row]
#         qty, value = None, None
#         sum_qty, sum_value = None, None
#         report_cols = report_row.find_elements_by_xpath('td')

#         if "日現在" in report_cols[0].text:
#             continue
#         if len(report_cols) <=1:
#             for _node in report_cols:
#                 logging.info("P1:{0}".format(_node.text))
#             continue

#         date_col_txt = report_cols[1].text
#         if "月" in date_col_txt:
#             if "日" in date_col_txt:
#                 if  re.match(bar_pattern, date_col_txt) is None and re.sub(void_dt_pattern, '', date_col_txt) != '':
#                     month = str(int(date_col_txt.split('月')[0])).zfill(2)
#                     day = str(int(date_col_txt.split('月')[1].split('日')[0])).zfill(2)
#                     dt = month+day
#                     qty = int(report_cols[2].text.replace(',', ''))
#                     value = int(report_cols[3].text.replace(',', ''))
#                     if qty is not None:
#                         report_result['daily'].append({'date':dt,'qty':qty,'value':value})
#                         logging.info("Data: {0}".format(report_result['daily'][-1]))
#                     else:
#                         logging.info("Data: No data")

#         #　計がきたらおしまい（ループ）
#         if report_row.text.startswith("計") and report_row.tag_name == 'tr':
#             report_cols = report_row.find_elements_by_xpath('td')
#             qty_col_txt = report_cols[2].text
#             if  re.match(bar_pattern, qty_col_txt) is None:
#                 sum_qty = int(report_cols[2].text.replace(',', ''))
#                 sum_value = int(report_cols[3].text.replace(',', ''))
#                 if sum_qty is not None:
#                     report_result['total'] = {'qty':sum_qty,'value':sum_value}
#                     logging.info("Sum : {0}".format(report_result['total']))
#                 else:
#                     logging.info("Sum: No data")
#             break
#     report_result['daily_total'] = len(report_result['daily'])
#     progress_report_result[type_no] = report_result
#     logging.info("Daily report: {0} rows are fetched.".format(len(report_result['daily'])))

# result.append(progress_report_result)
# logging.info("Done: {0}-{1}".format(progress_report_result['submit_date'],progress_report_result['edinet_code']))
# # close detail
# except Exception as e :
# logging.warning("Detail screen error(L3): {0}".format(e),exc_info=True)
# finally:
# agent.driver.switch_to.default_content()
# agent.driver.close() 

# except Exception as e :
# logging.warning("Detail screen error(L2): {0}".format(e),exc_info=True)
# finally:
# #　return search  result
# handle_array = agent.driver.window_handles
# agent.driver.switch_to.window(handle_array[0])

# except Exception as e :
# logging.warning("Detail screen error(L1): {0}".format(e))

# %%
import pandas as pd
rr = result[0]

def get_detail_table_result_df(detail_result):
    key_list = detail_result.keys
    key_list.remove('edinet_code')
    key_list.remove('submit_date')
    dfs = []
    for _key in key_list
        daily_df = pd.DataFrame(detail_result[_key]['daily'])
        daily_df['edinet_code'] = detail_result['edinet_code']
        daily_df['submit_date'] = detail_result['submit_date']
        dfs.append(daily_df)
    df = pd.concat(dfs,axis=0,ignore_index=True)
    return df
# Out:
#   File "<ipython-input-85-025f12e19a43>", line 9
#     for _key in key_list
#                         ^
# SyntaxError: invalid syntax

# %%
key_list = list(result[0].keys())

# %%
agent.driver.execute_script("window.open()")
new_window = agent.driver.window_handles.last
agent.driver.switch_to.window(new_window)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-b2a652870285> in <module>
#       1 agent.driver.execute_script("window.open()")
# ----> 2 new_window = agent.driver.window_handles.last
#       3 agent.driver.switch_to.window(new_window)
#
# AttributeError: 'list' object has no attribute 'last'

# %%
actions = ActionChains(agent.driver)
actions.key_down(Keys.COMMAND)
actions.click(page_link_btns[0])
actions.perform()

# %%
from selenium.webdriver.common.keys import Keys

# %%
class MAILER:
	def __init__(self):
		self.util = UTIL(version=ENV,service_name=SEAVICE_NAME)

		
		# read config and set
		self.util.read_config(MAIL_CONFIG)
		self.from_addr = self.util.config['FROM_ADDRESS']
		self.url_smtp =  self.util.config['URL_SMTP']
		self.port_smtp = self.util.config['PORT_SMTP']
		self.addr_login = self.util.config['LOGIN_ADDRESS']
		self.pw_login = self.util.config['LOGIN_PW']
		self.service_name = self.util.service_name
		# self.obj_msg = {}

	def read_ls_to_address(self):
		try:
			self.ls_to_addr = []
			with open(MAIL_TO_LIST,encoding = 'utf-8') as f:
				for _line  in csv.reader(f):
					for _address in _line : 
						self.ls_to_addr.append(_address)
						self.util.logger.info('[OK]Add send email list: %s',_address)
			self.util.logger.info('[OK]Get all address list')

		except Exception as e:
			self.util.logger.warning('[NG]Cannot read .csv of TO ADDR LIST:',e)
			return False

		return True




	def set_smtp_obj(self):
		try:
			self.obj_smtp = smtplib.SMTP(self.url_smtp, self.port_smtp)
			self.obj_smtp.ehlo()
			self.obj_smtp.starttls()
			self.obj_smtp.ehlo()
			self.obj_smtp.login(self.addr_login, self.pw_login)
			self.util.logger.info('[OK]Get smtp object')
		except Exception as e:
			self.util.logger.warning('[OK]Cannot get smtp object:',e)
			return False
		return True


	def exec_send(self):

		if not self.obj_smtp is None:
			try:
				self.util.logger.info('[・]Mail is sending for %s',str(self.ls_to_addr))
				self.obj_smtp.sendmail(self.from_addr, self.ls_to_addr, self.obj_msg.as_string())
				self.util.logger.info('[OK]Mail is sent')
				self.obj_smtp.close()
				return True
			except Exception as e:
				self.util.logger.warning('[NG]Cannot send mail: %s',e)		
				return False
		else:
			self.util.logger.warning('[NG]No smtp obj')	
			return False


	def make_content(self,subject, body):
		try:
			self.obj_msg = MIMEMultipart('alternative')
			part = MIMEText(self.finalize_html(body),'html')
			self.obj_msg['Subject'] = subject
			self.obj_msg['From']= self.from_addr
			self.obj_msg['To']	= ", ".join(self.ls_to_addr)
			self.obj_msg['Date']= formatdate()
			self.obj_msg.attach(part)
			self.util.logger.info('[OK]Get mail contents object')
		except Exception as e:
			self.util.logger.warning('[NG]Cannot make mail: %s',e)	
			return False

		return True

	def finalize_html(self,body):
		# add credit
		body += "<br>"
		body += "SENT BY "+self.service_name
		body += "<br>"
		return body

# %%
class NIKKEI:
	def __init__(self):
		self.agent = ACCESS()
		self.util = UTIL(version=ENV,service_name=SEAVICE_NAME)
		self.util.read_config(ELICA_CONFIG)
		self.url_login = 'https://www.nikkei.com/login'
		self.url_logout= 'https://regist.nikkei.com/ds/etc/accounts/logout'
		self.util.logger.info('[OK]NIKKEI INIT')


	def get_edition_paper(self,obj_dt=None,type='en'):
		# set dt
		if obj_dt is None:
			obj_dt = self.util.dt_init

		# set edition
		str_edition_paper=  "morning" if obj_dt.hour < 15 else "evening"

		# translate
		if type=='ja':
			dct_en_ja = {'morning':'朝','evening':'夕'}
			str_edition_paper = dct_en_ja[str_edition_paper]

		return str_edition_paper

	def get_paper_url(self,obj_dt=None):

		# set dt
		if obj_dt is None:
			obj_dt = self.util.dt_init

		# construct url
		url_paper = 'https://www.nikkei.com/paper/'+self.get_edition_paper(obj_dt)+'/?b='+"{0:%Y%m%d}".format(obj_dt)+'&d=0' 

		return url_paper

	def get_contents_in_paper(self):

		# get session
		self.logout()
		self.login()

		# get paper obj 
		is_obj = self.agent.to_page(self.get_paper_url(),**{'waittime':30})

		# make subject
		str_edition = self.get_edition_paper(obj_dt=None,type='ja')
		str_subject = "{0:%Y%m%d}".format(self.util.dt_init)+'日経紙面('+str_edition+'刊)一覧'

		if is_obj:

			self.util.logger.info('[・]Scraping Web page..')
			obj_content = self.scrape_paper()

			# discard session
			self.logout()
			self.util.logger.info('[OK]Get content from web pagesucessfly')
			self.agent.del_driver()

		else:
			self.util.logger.warning('[NG]Access is failed : May be not available today?')
			str_subject = '[NG]'+str_subject
			obj_content = None

		return  str_subject, obj_content

	def login(self):
		self.agent.get_login_page(self.url_login, allow_revisit=True, **{'waittime':10,'timeout_sec':120}	)
		self.agent.driver.find_element_by_id('LA7010Form01:LA7010Email').send_keys(self.util.config['ID'])
		self.agent.driver.find_element_by_id('LA7010Form01:LA7010Password').send_keys(self.util.config['PW'])
		self.agent.driver.find_element_by_class_name("btnM1").click();
		return 

	def logout(self):
		self.agent.get_logout_page(self.url_logout, allow_revisit=True, **{'waittime':10,'timeout_sec':120} )
		return 	

	def scrape_paper(self):
		ls_body = []
		try:
			ls_el_section = self.agent.driver.find_elements_by_css_selector('.cmn-section')

			for el_section in ls_el_section:
				# title
				try:
					section_title = el_section.find_element_by_css_selector('.cmnc-title').text
					if (section_title != '')&(section_title!='短信'): 
						# print("<"+section_title+">") 
						# body += ('<br>'+"＝＝"+section_title+"＝＝"+'<br>')
						dct_section = {}
						dct_section['section_name'] = section_title
						self.util.logger.info('[OK] %s',section_title)
						dct_section['ls_top_news'] = []

						#top news
						try:
							ls_el_article = el_section.find_elements_by_css_selector('.cmn-top_news')
							for el_article in  ls_el_article:
								try:
									ls_el_topic = el_article.find_elements_by_css_selector('.cmn-article_title')
									for el_topic in  ls_el_topic :
										topic_text =  el_topic.text.replace('<br>','')
										topic_text=  topic_text.strip()#空白削除

										dct_section['ls_top_news'].append(topic_text)
										self.util.logger.info('[OK] %s > (L)%s',section_title,topic_text)								
								except Exception as e:
									self.util.logger.warning('[NG] %s > (L)???',section_title,e)
									continue
						except Exception as e:
							self.util.logger.warning('[NG] %s : (L)No top news: %s ',section_title,e)

						#article
						dct_section['ls_article'] = []
						try:
							ls_el_article = el_section.find_elements_by_css_selector('.cmn-article_list')
							for el_article in  ls_el_article:
								try:
									ls_el_topic = el_article.find_elements_by_css_selector('.cmn-article_title')
									ls_small_topic = []
									for el_topic in ls_el_topic:

										#テキスト取得	
										topic_text = el_topic.text.replace('<br>','')
										topic_text=  topic_text.strip()#空白削除

										#すでにTOPnewsにある
										if topic_text in dct_section['ls_top_news']:
											self.util.logger.info('[・] %s > %s is already added',section_title,topic_text)										
											continue

										#すでに articleにある(small list外して)
										if topic_text in dct_section['ls_article']:
											self.util.logger.info('[・] %s > %s is already added',section_title,topic_text)										
											continue											

										#配置先チェック
										try:
											#小規模リスト
											if el_topic.tag_name == 'h5':

												#すでにls_small_topicある
												if topic_text in ls_small_topic:
													self.util.logger.info('[・] %s > > %s is already added',section_title,topic_text)										
												else:
													ls_small_topic.append(topic_text)
													self.util.logger.info('[OK] %s >  > %s',section_title,topic_text)	
											else:
												#直前までを挿入
												if len(ls_small_topic) > 0:
													dct_section['ls_article'].append(ls_small_topic)
												ls_small_topic = []

												#当該記事入れる
												dct_section['ls_article'].append(topic_text)
												self.util.logger.info('[OK] %s > %s',section_title,topic_text)
										except Exception as e:
											self.util.logger.warning('[NG] %s > %s (cannot insert): %s',section_title,topic_text,e)
											continue										

									#残存を挿入
									if len(ls_small_topic) > 0:
										dct_section['ls_article'].append(ls_small_topic)														
										
								except Exception as e:
									self.util.logger.warning('[NG] %s > ???(topic): %s',section_title,e)
									continue
						except Exception as e:
							self.util.logger.warning('[NG] %s > ???(topic list): %s',section_title,e)

						finally:
							ls_body.append(dct_section)

					else:
						self.util.logger.warning('[・] ???(section title is null or excluded * do it on purpose *)')

				except Exception as e:
					self.util.logger.warning('[NG] ???(No section title): %s',e)
					continue
		except Exception as e:
			self.util.logger.warning('[NG] ???(Cannot find sections): %s',e)

		return ls_body		


	@staticmethod
	def make_html(obj_content):
		body =''
		if not obj_content is None:
			for obj_section in obj_content:
				if isinstance(obj_section['section_name'],str):
					body += '=== {0} ===<br>'.format(obj_section['section_name']) 

				for obj_top_news in obj_section['ls_top_news']:
					if isinstance(obj_top_news,str):
						body += '　★ {0}<br>'.format(obj_top_news)
				for obj_article in obj_section['ls_article']:
					if isinstance(obj_article,str):
						body += '　・{0}<br>'.format(obj_article)
					else:
						for obj_small_article in obj_article:
							body += '　　・{0}<br>'.format(obj_small_article)
				body += '<br>'

		return body

class BLOOMBERG:
	def __init__(self):
		self.agent = ACCESS()
		self.util = UTIL(version=ENV,service_name=SEAVICE_NAME)
		self.util.read_config(ELICA_CONFIG)
		self.util.logger.info('[OK]BLOOMBERG INIT')

	def get_contents(self):

		# get paper obj 
		is_obj = self.agent.to_page('https://www.bloomberg.co.jp/',**{'waittime':5})

		# make subject		
		str_subject = "{0:%Y%m%d %H%M}".format(self.util.dt_init)+'Bloomberg一覧'

		if is_obj:
			self.util.logger.info('[・]Scraping Web page..')
			obj_content = self.scrape_paper()


			str_subject = "{0:%Y%m%d}".format(self.util.dt_init)+'Bloomberg('+"{0:%H:%M}".format(self.util.dt_init)+')一覧'

			# discard session
			self.util.logger.info('[OK]Get content from web pagesucessfly')
			self.agent.del_driver()
		else:
			self.util.logger.warning('[NG]Access is failed : May be not available')
			str_subject = '[NG]'+str_subject
			obj_content = None


		return  str_subject, obj_content


	def scrape_paper(self):
		ls_body = []
		try:
			self.agent.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
			self.agent.stop_driver(30)
			self.agent.driver.execute_script("window.scrollTo(0, 0);")
			self.agent.stop_driver(1)
			self.agent.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")		
			self.agent.stop_driver(30)
			self.agent.driver.execute_script("window.scrollTo(0, 0);")
			self.agent.stop_driver(1)

		except Exception as e:
			self.util.logger.warning('[NG] Driver scroll error: %s',e)
			return ls_body
		try:

			#hub-lazy-zones も含まれる
			ls_el_large_section = self.agent.driver.find_elements_by_css_selector('section.hub-zone-righty__content')
			self.util.logger.info('[・] Driver list up large %d sections',len(ls_el_large_section))
			# ls_el_section = self.agent.driver.find_elements_by_css_selector('article.mod-story')

			##### TOP ####
			el_large_section = ls_el_large_section[0]
			ls_el_section = el_large_section.find_elements_by_css_selector('section')
			ls_el_section = [ el_section for el_section in ls_el_section if el_section.get_attribute('class') in ['hero-module','story-list-module','section-front-header-module']]
			self.util.logger.info('[・] Driver list up %d top newses',len(ls_el_section))

			dct_section = {}
			dct_section['section_name'] = "TOP"
			ls_el_article = ls_el_section[0].find_elements_by_css_selector('article.mod-story')
			dct_section['ls_article'] = [ el_article.text for el_article in ls_el_article ]
			ls_body.append(dct_section)
			self.util.logger.info('[・] Driver get : %s',dct_section['section_name'])

			dct_section = {}
			dct_section['section_name'] = "Second"
			ls_el_article = ls_el_section[1].find_elements_by_css_selector('article.mod-story')
			dct_section['ls_article'] = [ el_article.text for el_article in ls_el_article ]
			ls_body.append(dct_section)
			self.util.logger.info('[・] Driver get : %s',dct_section['section_name'])

			dct_section = {}
			dct_section['section_name'] = "Topics"
			ls_el_article = ls_el_section[1].find_elements_by_css_selector('article.mod-story')
			dct_section['ls_article'] = [ el_article.text for el_article in ls_el_article ]
			ls_body.append(dct_section)
			self.util.logger.info('[・] Driver get : %s',dct_section['section_name'])

			##### SECOND ####
			el_large_section = ls_el_large_section[1]
			ls_el_section = el_large_section.find_elements_by_css_selector('section')
			ls_el_section = [ el_section for el_section in ls_el_section if el_section.get_attribute('class') in ['story-list-module','section-front-header-module']]
			self.util.logger.info('[・] Driver list up %d second newses',len(ls_el_section))

			dct_section = {}
			dct_section['section_name'] = ls_el_section[0].text
			ls_el_article = ls_el_section[1].find_elements_by_css_selector('article.mod-story')
			dct_section['ls_article'] = [ el_article.text for el_article in ls_el_article ]
			ls_body.append(dct_section)
			self.util.logger.info('[・] Driver get : %s',dct_section['section_name'])

			##### Small grids ####
			el_large_section = ls_el_large_section[2]
			ls_el_section = el_large_section.find_elements_by_css_selector('section')
			ls_el_section = [ el_section for el_section in ls_el_section if el_section.get_attribute('class') in ['grid-module']]
			self.util.logger.info('[・] Driver list up %d small newses',len(ls_el_section))

			for el_section in ls_el_section:
				
				dct_section = {}
				dct_section['section_name'] = el_section.find_element_by_css_selector('.grid-module__title').text
				ls_el_article = el_section.find_elements_by_css_selector('article.mod-story')
				dct_section['ls_article'] = [ el_article.text for el_article in ls_el_article ]
				ls_body.append(dct_section)
				self.util.logger.info('[・] Driver get : %s',dct_section['section_name'])

			self.util.logger.info('[OK] Driver get ALL expected contents')

		except Exception as e:
			self.util.logger.warning('[NG] Driver occur some error: %s',e)
			return ls_body


		return ls_body		


	@staticmethod
	def make_html(obj_content):
		body =''
		if not obj_content is None:
			for obj_section in obj_content:
				body += '=== {0} ===<br>'.format(obj_section['section_name']) 

				for obj_article in obj_section['ls_article']:
					body += '　・{0}<br>'.format(obj_article)

				body += '<br>'

		return body



def get_nikkei_and_mail():
	obj_nikkei = NIKKEI()

	str_subject,obj_content = obj_nikkei.get_contents_in_paper()
	# # save_pickle(obj_content,'content.pickle')
	# obj_content = read_pickle('content.pickle')
	body_html = obj_nikkei.make_html(obj_content)
	# save_pickle(body_html,'body.pickle')
	# str_subject = 'test'

	obj_mailer = MAILER()
	obj_mailer.set_smtp_obj()
	obj_mailer.read_ls_to_address()
	obj_mailer.make_content(str_subject,body_html)
	obj_mailer.exec_send()
	return 

def get_blbrg_and_mail():
	obj_blbrg = BLOOMBERG()

	str_subject,obj_content = obj_blbrg.get_contents()
	# # save_pickle(obj_content,'content.pickle')
	# obj_content = read_pickle('content.pickle')
	body_html = obj_blbrg.make_html(obj_content)
	# save_pickle(body_html,'body.pickle')
	# str_subject = 'test'

	obj_mailer = MAILER()
	obj_mailer.set_smtp_obj()
	obj_mailer.read_ls_to_address()
	obj_mailer.make_content(str_subject,body_html)
	obj_mailer.exec_send()
	return 

# def make_newspicks_mail():
# 	body = add_system_credit(newspicks_access())
# 	time_p_str =  "朝" if now.time().hour < 15 else "夕"
# 	subject = "{0:%Y%m%d}".format(now)+'Newspicks('+time_p_str+')一覧'
# 	return (body,subject)

def save_pickle(obj,name):
	# name = folder + name
	with open(name,'wb') as f:
		pickle.dump(obj,f)

def read_pickle(name):
	# name = folder + name
	with open(name,'rb') as f:
		obj = pickle.load(f)
	return obj



if __name__ == '__main__':
	get_nikkei_and_mail()
	get_blbrg_and_mail()
	# (body,subject) = make_nikkei_mail()
	# send_action(subject,body)

	# (body,subject) = make_newspicks_mail()
	# send_action(subject,body)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4db83e69fd66> in <module>
#     574
#     575 if __name__ == '__main__':
# --> 576         get_nikkei_and_mail()
#     577         get_blbrg_and_mail()
#     578         # (body,subject) = make_nikkei_mail()
#
# <ipython-input-2-4db83e69fd66> in get_nikkei_and_mail()
#     521
#     522 def get_nikkei_and_mail():
# --> 523         obj_nikkei = NIKKEI()
#     524
#     525         str_subject,obj_content = obj_nikkei.get_contents_in_paper()
#
# <ipython-input-2-4db83e69fd66> in __init__(self)
#     179 class NIKKEI:
#     180         def __init__(self):
# --> 181                 self.agent = ACCESS()
#     182                 self.util = UTIL(version=ENV,service_name=SEAVICE_NAME)
#     183                 self.util.read_config(ELICA_CONFIG)
#
# <ipython-input-2-4db83e69fd66> in __init__(self)
#       6
#       7                 #set log
# ----> 8                 self.util = UTIL(version=ENV,service_name=SEAVICE_NAME)
#       9                 self.util.read_config(ELICA_CONFIG)
#      10
#
# NameError: name 'UTIL' is not defined
